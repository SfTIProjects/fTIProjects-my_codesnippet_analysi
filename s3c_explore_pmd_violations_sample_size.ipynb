# %%
import time
from datetime import timedelta

import html
import re

import os
import ntpath

import subprocess as sp

import numpy as np
import pandas as pd
import xml.etree.ElementTree as et

import dask
import dask.dataframe as dd
import dask.bag as bd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# %% [markdown]
# ## Read csv files Java Answers

# %%
df = dd.read_csv('pmdcodesnippetsviolations_csv/PMDJavaCodeSnippetsViolations*.csv', engine='python', error_bad_lines=False, warn_bad_lines=False, dtype=object)

# %% [markdown]
# ## Start a Dask cluster using SLURM jobs as workers

# %%
#http://jobqueue.dask.org/en/latest/generated/dask_jobqueue.SLURMCluster.html
dask.config.set(
    {
        "distributed.worker.memory.target": False,  # avoid spilling to disk
        "distributed.worker.memory.spill": False,  # avoid spilling to disk
    }
)
cluster = SLURMCluster(
    cores=10, #cores=24, # we set each job to have 1 Worker, each using 10 cores (threads) and 8 GB of memory
    processes=2,
    memory="8GiB",
    walltime="0-00:30",# walltime="0-00:50",
    log_directory="../dask/logs",  # folder for SLURM logs for each worker
    local_directory="../dask",  # folder for workers data
)
# Out:
# /opt/nesi/CS400_centos7_bdw/Python/3.9.5-gimkl-2020a/lib/python3.9/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42475 instead
#   warnings.warn(

# %% [markdown]
# Spawn between 20 to 100 workers and connect a client to be able use them.

# %%
#cluster.scale(n=20) # ask for 20 jobs or workers
# This also works with adaptive clusters. This automatically launches and kill workers based on load.
# we tell our cluster to autoscale between 10 and 20 workers depending on the load
cluster.adapt(minimum_jobs=10, maximum_jobs=200)
#cluster.adapt(maximum_jobs=20)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://192.168.94.140:46208' processes=0 threads=0, memory=0 B>

# %%
df
# Out:
# Dask DataFrame Structure:
#                 beginline endline begincolumn endcolumn    rule ruleset   class externalInfoUrl priority    text
# npartitions=204
#                    object  object      object    object  object  object  object          object   object  object
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# ...                   ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# Dask Name: read-csv, 204 tasks

# %%
pmd_codeviolations_init_len = df.shape[0].compute()
print('Initial number of volations {}'.format(pmd_codeviolations_init_len))
# Out:
# Initial number of volations 4896537

# %%
# drop empty columns
df = df[~df['class'].isna()] # Drop rows that have NaN in the Code column

# %%
pmd_codeviolations_nonan_len =df.shape[0].compute()
print('Number of violations after removing the nans in the class column {}'.format(pmd_codeviolations_nonan_len))
# Out:
# Number of violations after removing the nans in the class column 4887262

# %%
print('Difference {}'.format(pmd_codeviolations_init_len - pmd_codeviolations_nonan_len))
# Out:
# Difference 9275

# %%
# drop classes that do not have this pattern e.g., Code_10000096_9914015_1959_0
#df = df[df['class'].str.contains('^Code_\d+_\d+_\d+_\d+', regex=True)]
df = df[df['class'].str.contains('^Code_\d+_\d+_\d+_\d+$', regex=True)]

# %%
pmd_codeviolations_unkownclass_len = df.shape[0].compute()
print('Number of violations after removing the onces caused by unknown class e.g. inner classes {}'.format(pmd_codeviolations_nonan_len))
# Out:
# Number of violations after removing the onces caused by unknown class e.g. inner classes 4887262

# %%
print('Difference {}'.format(pmd_codeviolations_nonan_len - pmd_codeviolations_unkownclass_len))
# Out:
# Difference 499061

# %% [markdown]
# ### Group dataframe by ruleset

# %%
grp_df = df.groupby('ruleset')

# %%
# get just the 1st of each group
grp_df.first().head()
# Out:
#                beginline endline begincolumn endcolumn  \
# ruleset
# Best Practices         8       8           9        26
# Code Style             1      11           8         1
# Design                 1      11          43         1
# Documentation         20      21          62         9
# Error Prone            2       2          16        23
#
#                                       rule                         class  \
# ruleset
# Best Practices               SystemPrintln  Code_10000096_9914015_1959_0
# Code Style          ClassNamingConventions  Code_10000096_9914015_1959_0
# Design                     UseUtilityClass  Code_10000096_9914015_1959_0
# Documentation   UncommentedEmptyMethodBody     Code_1000205_995514_363_0
# Error Prone     BeanMembersShouldSerialize  Code_10000948_10000578_714_1
#
#                                                   externalInfoUrl priority  \
# ruleset
# Best Practices  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# Code Style      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# Design          https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# Documentation   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# Error Prone     https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                              text
# ruleset
# Best Practices                         System.out.println is used
# Code Style      The class name 'Code_10000096_9914015_1959_0' ...
# Design          All methods are static.  Consider using a util...
# Documentation                          Document empty method body
# Error Prone     Found non-transient, non-static member. Please...

# %%
# Get all the values belonging to, say Best Practices
best_practices = grp_df.get_group('Best Practices').compute()
best_practices.head()
# Out:
#    beginline endline begincolumn endcolumn                rule  \
# 11         8       8           9        26       SystemPrintln
# 26        18      18          13        30       SystemPrintln
# 38        44      44          24        24    UnusedAssignment
# 74         3       3          21        24  UnusedPrivateField
# 78        10      10          31        39  UnusedPrivateField
#
#            ruleset                          class  \
# 11  Best Practices   Code_10000096_9914015_1959_0
# 26  Best Practices   Code_10000439_9999961_2190_4
# 38  Best Practices   Code_10000439_9999961_2190_4
# 74  Best Practices  Code_10001108_10000983_1098_0
# 78  Best Practices  Code_10001108_10000983_1098_0
#
#                                       externalInfoUrl priority  \
# 11  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 26  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 38  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 74  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 78  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                  text
# 11                         System.out.println is used
# 26                         System.out.println is used
# 38  The initializer for variable 'read' is never u...
# 74        Avoid unused private fields such as 'mBoo'.
# 78   Avoid unused private fields such as 'mOnChange'.

# %%
# reset index
best_practices.reset_index(drop=True, inplace=True)
best_practices.head()
# Out:
#   beginline endline begincolumn endcolumn                rule         ruleset  \
# 0         8       8           9        26       SystemPrintln  Best Practices
# 1        18      18          13        30       SystemPrintln  Best Practices
# 2        44      44          24        24    UnusedAssignment  Best Practices
# 3         3       3          21        24  UnusedPrivateField  Best Practices
# 4        10      10          31        39  UnusedPrivateField  Best Practices
#
#                            class  \
# 0   Code_10000096_9914015_1959_0
# 1   Code_10000439_9999961_2190_4
# 2   Code_10000439_9999961_2190_4
# 3  Code_10001108_10000983_1098_0
# 4  Code_10001108_10000983_1098_0
#
#                                      externalInfoUrl priority  \
# 0  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 1  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 2  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 3  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 4  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                 text
# 0                         System.out.println is used
# 1                         System.out.println is used
# 2  The initializer for variable 'read' is never u...
# 3        Avoid unused private fields such as 'mBoo'.
# 4   Avoid unused private fields such as 'mOnChange'.

# %%
# Randomly select that number
#https://datatofish.com/random-rows-pandas-dataframe/
best_practices_ran = best_practices.sample(n=46)
best_practices_ran.head()
# Out:
#        beginline endline begincolumn endcolumn                  rule  \
# 49708          2       2          15        17   UnusedPrivateMethod
# 251518        27      27          17        34         SystemPrintln
# 20201          7       7           5        23  AvoidPrintStackTrace
# 377309         5       5           5        22         SystemPrintln
# 409483        17      17          13        28         SystemPrintln
#
#                ruleset                          class  \
# 49708   Best Practices  Code_41861554_33558564_1165_1
# 251518  Best Practices  Code_64915718_64914778_204_14
# 20201   Best Practices   Code_39106811_39106614_343_0
# 377309  Best Practices   Code_22691362_22690261_129_1
# 409483  Best Practices  Code_26009252_20134992_4602_1
#
#                                           externalInfoUrl priority  \
# 49708   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 251518  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 20201   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 377309  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 409483  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
#
#                                                      text
# 49708         Avoid unused private methods such as 'h()'.
# 251518                         System.out.println is used
# 20201   Avoid printStackTrace(); use a logger call ins...
# 377309                         System.out.println is used
# 409483                           System.out.print is used

# %% [markdown]
# ## Make a folder in that directory

# %%
## Make a folder in that directory
#folder = '{}/sample_pmd_csv'.format(common_path)
folder = 'pmd_sample'.format()
# output: path/to/Post.csv => path/to
mkdir_cmd = 'mkdir {}'.format(folder)
cmd = sp.run(
    mkdir_cmd, # command
    capture_output=True,
    text=True,
    shell=True
)

# %%
#print(folder)

# %%
#create a folder

# %%
# Select these files and dump them somewhere
# copy these files to another folder
for filename_to_copy in best_practices_ran['class']:
    #print('{}.java'.format(filename))
    file_to_copy = '{}.java'.format(filename_to_copy)
    copy_file_cmd = 'cp codesnippets_java/{} {}'.format(file_to_copy, folder)
    cmd = sp.run(
        copy_file_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )

# %% [raw]
# # Add java extension to the class name
# def app_java_ext(x):
#     return '{}.java'.format(x)
#
# best_practices_ran['class'] = best_practices_ran['class'].apply(app_java_ext)
# best_practices_ran.head()

# %% [raw]
# #' '.join(list(best_practices_ran['class']))
# files_to_copy = ' '.join(list(best_practices_ran['class']))
# files_to_copy
