# %%
import time
from datetime import timedelta
import html

import subprocess as sp

import pandas as pd
import dask
import dask.dataframe as dd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# %% [markdown]
# ## Read csv files Java Answers

# %%
df = dd.read_csv('spotbugreports_wt_idx_csv/spotbugReport*.csv', engine='python', error_bad_lines=False, warn_bad_lines=False, dtype=object)

# %% [markdown]
# #### Explore dataframe

# %%
## explore one patition
#one_pat_df = df.partitions[1].compute()

# %%
df
# Out:
# Dask DataFrame Structure:
#                 category    type sourcefile shortMsg bugline
# npartitions=577
#                   object  object     object   object  object
#                      ...     ...        ...      ...     ...
# ...                  ...     ...        ...      ...     ...
#                      ...     ...        ...      ...     ...
#                      ...     ...        ...      ...     ...
# Dask Name: read-csv, 577 tasks

# %% [markdown]
# ## Start a Dask cluster using SLURM jobs as workers

# %%
#http://jobqueue.dask.org/en/latest/generated/dask_jobqueue.SLURMCluster.html
dask.config.set(
    {
        "distributed.worker.memory.target" : False,  # avoid spilling to disk
        "distributed.worker.memory.spill" : False,  # avoid spilling to disk
    }
)
cluster = SLURMCluster(
    cores=10, #cores=24, # we set each job to have 1 Worker, each using 10 cores (threads) and 8 GB of memory
    processes=2,
    memory="8GiB",
    walltime="0-00:30",# walltime="0-00:50",
    log_directory="../dask/logs",  # folder for SLURM logs for each worker
    local_directory="../dask",  # folder for workers data
)

# %% [markdown]
# Spawn between 20 to 100 workers and connect a client to be able use them.

# %%
#cluster.scale(n=20) # ask for 20 jobs or workers
# This also works with adaptive clusters. This automatically launches and kill workers based on load.
# we tell our cluster to autoscale between 10 and 20 workers depending on the load
cluster.adapt(minimum_jobs=10, maximum_jobs=200)
#cluster.adapt(maximum_jobs=20)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://192.168.94.140:45527' processes=0 threads=0, memory=0 B>

# %%
df_init_len = df.shape[0].compute()
print('Initial number of volations {}'.format(df_init_len))
# Out:
# Initial number of volations 138036

# %%
df.head()
# Out:
#       category              type                          sourcefile  \
# 0  PERFORMANCE  URF_UNREAD_FIELD  Code_10203353_10202514_4576_2.java
# 1  PERFORMANCE  URF_UNREAD_FIELD  Code_10203353_10202514_4576_2.java
# 2  PERFORMANCE  URF_UNREAD_FIELD  Code_10203353_10202514_4576_2.java
# 3  PERFORMANCE  URF_UNREAD_FIELD  Code_10306917_10306647_1215_0.java
# 4  PERFORMANCE  URF_UNREAD_FIELD  Code_10306917_10306647_1215_0.java
#
#        shortMsg    bugline
# 0  Unread field  lines 1-2
# 1  Unread field     noline
# 2  Unread field     line 2
# 3  Unread field     line 2
# 4  Unread field  lines 1-2

# %%
#df.tail()

# %%
# get all the records that nave the line where the error occured
df = df[~(df.bugline == 'noline')]

# %%
# originally, distinct number of type is 41545, 
# however, Sport bug reports errors such that some are repeated more than once for one class
# hence ve now have 98121
df.index.shape[0].compute()
# Out:
# 98121

# %%
df.head()
# Out:
#       category              type                          sourcefile  \
# 0  PERFORMANCE  URF_UNREAD_FIELD  Code_10203353_10202514_4576_2.java
# 2  PERFORMANCE  URF_UNREAD_FIELD  Code_10203353_10202514_4576_2.java
# 3  PERFORMANCE  URF_UNREAD_FIELD  Code_10306917_10306647_1215_0.java
# 4  PERFORMANCE  URF_UNREAD_FIELD  Code_10306917_10306647_1215_0.java
# 6  PERFORMANCE  URF_UNREAD_FIELD  Code_10488060_10487618_3943_0.java
#
#        shortMsg    bugline
# 0  Unread field  lines 1-2
# 2  Unread field     line 2
# 3  Unread field     line 2
# 4  Unread field  lines 1-2
# 6  Unread field     line 2

# %% [markdown]
# ### Count the number of times each 'type' occured

# %%
#https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
#viol_count_df = pd.DataFrame(df.groupby('category')['category'].count().compute())
viol_count_df = pd.DataFrame(df.groupby('type')['type'].count().compute())
# rename the column to total
viol_count_df.columns=['total']
# drop the index level
viol_count_df = viol_count_df.reset_index()
viol_count_df
# Out:
#                                                  type  total
# 0                                      DM_STRING_CTOR   3263
# 1                          SIC_INNER_SHOULD_BE_STATIC   5567
# 2                                 SS_SHOULD_BE_STATIC   2831
# 3                                    URF_UNREAD_FIELD  60510
# 4                                    UUF_UNUSED_FIELD  16932
# 5                              WMI_WRONG_MAP_ITERATOR    686
# 6                                  MS_SHOULD_BE_FINAL    894
# 7                                 MS_FINAL_PKGPROTECT    229
# 8                           DM_NEXTINT_VIA_NEXTDOUBLE   1892
# 9                                       MS_PKGPROTECT    711
# 10                        DMI_BLOCKING_METHODS_ON_URL      9
# 11                                      EI_EXPOSE_REP    683
# 12                                     EI_EXPOSE_REP2    552
# 13                           DMI_CONSTANT_DB_PASSWORD    633
# 14                        UPM_UNCALLED_PRIVATE_METHOD    141
# 15                     DM_BOXED_PRIMITIVE_FOR_PARSING   1327
# 16                                DM_STRING_VOID_CTOR    609
# 17                        DM_BOXED_PRIMITIVE_TOSTRING     22
# 18                                DM_NEW_FOR_GETCLASS     53
# 19                              DMI_EMPTY_DB_PASSWORD    144
# 20         DP_CREATE_CLASSLOADER_INSIDE_DO_PRIVILEGED      6
# 21                    BX_UNBOXING_IMMEDIATELY_REBOXED    107
# 22                     DM_BOXED_PRIMITIVE_FOR_COMPARE     67
# 23                                      MS_EXPOSE_REP    115
# 24                              EI_EXPOSE_STATIC_REP2     40
# 25                                              DM_GC     45
# 26                   MS_MUTABLE_COLLECTION_PKGPROTECT     27
# 27                SBSC_USE_STRINGBUFFER_CONCATENATION      5
# 28  REFLF_REFLECTION_MAY_INCREASE_ACCESSIBILITY_OF...     11
# 29                MS_SHOULD_BE_REFACTORED_TO_BE_FINAL      5
# 30                             DMI_COLLECTION_OF_URLS      5

# %% [markdown]
# ### Calculate the percentage

# %%
viol_count_df['percent'] = (viol_count_df['total']/ viol_count_df['total'].sum())*100

# %%
viol_count_df.head()
# Out:
#                          type  total    percent
# 0              DM_STRING_CTOR   3263   3.325486
# 1  SIC_INNER_SHOULD_BE_STATIC   5567   5.673607
# 2         SS_SHOULD_BE_STATIC   2831   2.885213
# 3            URF_UNREAD_FIELD  60510  61.668756
# 4            UUF_UNUSED_FIELD  16932  17.256245

# %% [markdown]
# ### Calculate number to be sampled per ruleset
# - to represent the distribution of the types of violations

# %%
import math
def comp_smpl_no(x):
    x = round((x/100)*384)
    if x < 1:
        x = 1
    return x

# Randomly select that number
#https://datatofish.com/random-rows-pandas-dataframe/
#chk_style_ran = df.sample(frac=384/len(df), replace=None, random_state=10)
viol_count_df['sample_size_384'] = viol_count_df['percent'].apply(comp_smpl_no)
viol_count_df.head()
# Out:
#                          type  total    percent  sample_size_384
# 0              DM_STRING_CTOR   3263   3.325486               13
# 1  SIC_INNER_SHOULD_BE_STATIC   5567   5.673607               22
# 2         SS_SHOULD_BE_STATIC   2831   2.885213               11
# 3            URF_UNREAD_FIELD  60510  61.668756              237
# 4            UUF_UNUSED_FIELD  16932  17.256245               66

# %% [markdown]
# ### Final Sample Used

# %%
viol_count_df['sample_size_384'].sum()
# Out:
# 396

# %% [markdown]
# ### Group by Source

# %%
grp_df = df.groupby('type')

# %%
grp_dfs = []

# %%
for vio, sample_size in zip(viol_count_df['type'], viol_count_df['sample_size_384']): # e.g., Best Practices, Coding Style, Design
    # get the last word after dots delemeter as well as convert to lower case
    subfolder = vio.lower()
    
    # Get all the values belonging to source violations, say ArrayType
    vio_grp = grp_df.get_group(vio)
    vio_grp = vio_grp.reset_index(drop=True).compute()
    #vio_grp.head()
    
    # Randomly select that number
    #https://datatofish.com/random-rows-pandas-dataframe/
    vio_grp_ran = vio_grp.sample(n=sample_size, random_state=10)
    # add the subfolder to get java file
    vio_grp_ran['sample_subfolder'] = subfolder
    # append the data frame to a list
    grp_dfs.append(vio_grp_ran)
    
    
    ## Make a folder in that directory
    folder = 'sample_sptbg'
    # output: path/to/Post.csv => path/to
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    ## Make a folder in that directory
    folder = 'sample_sptbg/{}'.format(subfolder)
    # output: path/to/Post.csv => path/to
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    # copy list of sample java files into the destination 
    for filename_to_copy in vio_grp_ran['sourcefile']:
        file_to_copy = '{}'.format(filename_to_copy)
        copy_file_cmd = 'cp codesnippets_java/{} {}'.format(file_to_copy, folder)
        cmd = sp.run(
            copy_file_cmd, # command
            capture_output=True,
            text=True,
            shell=True
        )

# %% [markdown]
# ### Observed Test

# %%
# Combine all the group dataframe
com_grp_dfs = pd.concat(grp_dfs)
com_grp_dfs.head()
# Out:
#        category            type                          sourcefile  \
# 10  PERFORMANCE  DM_STRING_CTOR    Code_7114630_7114546_2987_0.java
# 4   PERFORMANCE  DM_STRING_CTOR  Code_19938540_19938482_2572_1.java
# 7   PERFORMANCE  DM_STRING_CTOR  Code_43791827_43791584_1968_0.java
# 1   PERFORMANCE  DM_STRING_CTOR  Code_20166109_9607903_2381_12.java
# 7   PERFORMANCE  DM_STRING_CTOR     Code_40367841_4570037_54_8.java
#
#                                              shortMsg  bugline  \
# 10  Method invokes inefficient new String(String) ...   line 2
# 4   Method invokes inefficient new String(String) ...   line 2
# 7   Method invokes inefficient new String(String) ...   line 2
# 1   Method invokes inefficient new String(String) ...  line 11
# 7   Method invokes inefficient new String(String) ...   line 2
#
#    sample_subfolder
# 10   dm_string_ctor
# 4    dm_string_ctor
# 7    dm_string_ctor
# 1    dm_string_ctor
# 7    dm_string_ctor

# %% [markdown]
# ### Sort them in order

# %%
#com_grp_dfs.sort_values('sourcefile', ascending=True, inplace=True)
com_grp_dfs.sort_values(['sample_subfolder','sourcefile'], ascending=[True, True], inplace=True)

# %%
com_grp_dfs.head()#com_grp_dfs.sort_values('sourcefile', ascending=True, inplace=True)
com_grp_dfs.sort_values(['sample_subfolder','sourcefile'], ascending=[True, True], inplace=True)

# %%
for cat, subfol, name, ln, msg in zip(com_grp_dfs['category'], com_grp_dfs['sample_subfolder'], com_grp_dfs['sourcefile'], com_grp_dfs['bugline'], com_grp_dfs['shortMsg']):
    print('sample_sptbg/{}/{} : {} ==> {} ({})'.format(subfol, name, ln, msg, cat))
# Out:
# sample_sptbg/bx_unboxing_immediately_reboxed/Code_33182091_33177256_1548_8.java : line 3 ==> Boxed value is unboxed and then immediately reboxed (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_compare/Code_38933380_38933098_721_1.java : line 7 ==> Boxing a primitive to compare (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_parsing/Code_13066419_13066225_2049_0.java : lines 1-2 ==> Boxing/unboxing to parse a primitive (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_parsing/Code_23017269_23014428_350_0.java : lines 1-8 ==> Boxing/unboxing to parse a primitive (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_parsing/Code_58049037_58048233_1212_0.java : line 29 ==> Boxing/unboxing to parse a primitive (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_parsing/Code_587564_587280_493_4.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_for_parsing/Code_9722839_9722360_2045_0.java : line 6 ==> Unread field (PERFORMANCE)
# sample_sptbg/dm_boxed_primitive_tostring/Code_68072788_68072383_281_0.java : line 2 ==> Method allocates a boxed primitive just to call toString (PERFORMANCE)
# sample_sptbg/dm_gc/Code_41059695_41057015_3527_0.java : line 2 ==> Explicit garbage collection; extremely dubious except in benchmarking code (PERFORMANCE)
# sample_sptbg/dm_new_for_getclass/Code_24136241_24136055_645_0.java : line 3 ==> Method allocates an object, only to get the class object (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_23046879_23046821_1833_0.java : lines 3-14 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_26352429_26351874_96_5.java : line 2 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_32234958_32234832_4119_0.java : line 2 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_36250072_36250039_990_0.java : lines 1-10 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_36604782_36604595_3412_2.java : lines 3-26 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_36902808_36902784_1671_1.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/dm_nextint_via_nextdouble/Code_64384385_64379577_3685_6.java : line 2 ==> Use the nextInt method of Random rather than nextDouble to generate a random integer (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_14123632_14123565_1795_0.java : line 5 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_16477639_16475317_1582_6.java : lines 1-52 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_17260213_2506077_2318_0.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_19938540_19938482_2572_1.java : line 2 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_20166109_9607903_2381_12.java : line 11 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_24780806_24780743_1044_2.java : line 10 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_40123855_7107297_91_0.java : line 4 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_40188889_40188409_158_0.java : line 3 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_40367841_4570037_54_8.java : line 2 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_43791827_43791584_1968_0.java : line 2 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_55626386_55625743_2126_2.java : lines 1-13 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_7072226_7072135_822_0.java : line 2 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_ctor/Code_7114630_7114546_2987_0.java : line 2 ==> Method invokes inefficient new String(String) constructor (PERFORMANCE)
# sample_sptbg/dm_string_void_ctor/Code_58677805_58676631_3312_1.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/dm_string_void_ctor/Code_62761488_51394086_735_1.java : lines 1-2 ==> Method invokes inefficient new String() constructor (PERFORMANCE)
# sample_sptbg/dmi_blocking_methods_on_url/Code_41262325_41114334_1295_0.java : line 45 ==> The equals and hashCode methods of URL are blocking (PERFORMANCE)
# sample_sptbg/dmi_collection_of_urls/Code_53552030_53539388_1455_1.java : line 2 ==> Maps and sets of URLs can be performance hogs (PERFORMANCE)
# sample_sptbg/dmi_constant_db_password/Code_34233643_34233558_894_3.java : lines 5-30 ==> Hardcoded constant database password (SECURITY)
# sample_sptbg/dmi_constant_db_password/Code_41987975_41987900_495_14.java : line 2 ==> Hardcoded constant database password (SECURITY)
# sample_sptbg/dmi_empty_db_password/Code_26412534_26411343_1431_1.java : line 2 ==> Empty database password (SECURITY)
# sample_sptbg/dp_create_classloader_inside_do_privileged/Code_23417665_23415288_1793_1.java : lines 2-5 ==> Classloaders should only be created inside doPrivileged block (MALICIOUS_CODE)
# sample_sptbg/ei_expose_rep/Code_22200286_22200047_1190_1.java : lines 2-13 ==> May expose internal representation by returning reference to mutable object (MALICIOUS_CODE)
# sample_sptbg/ei_expose_rep/Code_22696864_22637077_1008_1.java : lines 3-31 ==> May expose internal representation by returning reference to mutable object (MALICIOUS_CODE)
# sample_sptbg/ei_expose_rep/Code_51429705_29454511_746_0.java : line 2 ==> May expose internal representation by returning reference to mutable object (MALICIOUS_CODE)
# sample_sptbg/ei_expose_rep2/Code_29796038_23429775_86_0.java : line 13 ==> May expose internal representation by incorporating reference to mutable object (MALICIOUS_CODE)
# sample_sptbg/ei_expose_rep2/Code_35257920_35257673_2336_0.java : line 9 ==> May expose internal representation by incorporating reference to mutable object (MALICIOUS_CODE)
# sample_sptbg/ei_expose_static_rep2/Code_4154300_4154239_452_3.java : line 2 ==> Unread field (MALICIOUS_CODE)
# sample_sptbg/ms_expose_rep/Code_31222803_31222531_20_0.java : line 6 ==> Public static method may expose internal representation by returning array (MALICIOUS_CODE)
# sample_sptbg/ms_final_pkgprotect/Code_13636442_13636094_273_1.java : line 11 ==> Field should be both final and package protected (MALICIOUS_CODE)
# sample_sptbg/ms_mutable_collection_pkgprotect/Code_37042254_3859288_1479_1.java : line 14 ==> Field is a mutable collection which should be package protected (MALICIOUS_CODE)
# sample_sptbg/ms_pkgprotect/Code_17247005_17246969_514_0.java : line 2 ==> Field should be package protected (MALICIOUS_CODE)
# sample_sptbg/ms_pkgprotect/Code_19572511_19569446_1002_0.java : lines 3-88 ==> Field should be package protected (MALICIOUS_CODE)
# sample_sptbg/ms_pkgprotect/Code_31008099_31007494_148_3.java : line 6 ==> Field should be package protected (MALICIOUS_CODE)
# sample_sptbg/ms_should_be_final/Code_25388868_5643605_3090_0.java : line 12 ==> Field isn't final but should be (MALICIOUS_CODE)
# sample_sptbg/ms_should_be_final/Code_33253160_33252242_3821_2.java : line 7 ==> Field isn't final but should be (MALICIOUS_CODE)
# sample_sptbg/ms_should_be_final/Code_60150526_44390404_2789_1.java : line 5 ==> Field isn't final but should be (MALICIOUS_CODE)
# sample_sptbg/ms_should_be_refactored_to_be_final/Code_34549369_34549118_2393_0.java : line 3 ==> Field isn't final but should be refactored to be so (MALICIOUS_CODE)
# sample_sptbg/reflf_reflection_may_increase_accessibility_of_field/Code_54822886_54819923_1546_0.java : line 5 ==> Public method uses reflection to modify a field it gets in its parameter which could increase the accessibility of any class (MALICIOUS_CODE)
# sample_sptbg/sbsc_use_stringbuffer_concatenation/Code_17881177_17878669_1834_0.java : line 2 ==> Method concatenates strings using + in a loop (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_10027403_10022420_1771_1.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_12774860_12774842_604_0.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_12938982_12938964_1299_1.java : line 4 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_12998171_12998154_4194_1.java : line 3 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_13377151_13377050_2636_0.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_14990515_14990184_3213_2.java : line 5 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_18494638_18494282_1770_0.java : lines 2-20 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_20964678_20964466_5627_0.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_21375342_21375053_2437_2.java : line 4 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_24192123_24191959_1732_2.java : line 2 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_29521327_29521158_1484_7.java : lines 5-15 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_30543665_30542695_2208_0.java : line 3 ==> Unread field (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_31092749_31092705_1638_2.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_33871011_33870914_1236_7.java : lines 6-15 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_4642839_4642784_376_0.java : line 3 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_48626109_48613087_402_0.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_50927821_50927601_243_0.java : line 2 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_51172825_34627462_90_0.java : lines 2-11 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_51603_51582_1221_0.java : line 4 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_57393523_57393302_611_10.java : lines 5-8 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_59148141_59148015_613_0.java : line 12 ==> Should be a static inner class (PERFORMANCE)
# sample_sptbg/sic_inner_should_be_static/Code_6187373_6187293_3502_1.java : line 3 ==> Unread field (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_10335890_10335837_2906_1.java : line 3 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_19323800_19322575_1907_0.java : line 3 ==> Unread field (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_24714727_24714706_287_5.java : line 2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_28243990_28242431_4568_2.java : lines 1-4 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_32222590_32222526_3885_0.java : line 3 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_32411370_32410949_2577_2.java : line 2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_40304222_40304160_4124_4.java : line 2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_40390212_40387840_753_1.java : line 3 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_41707093_41706863_788_2.java : lines 1-2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_47078624_37851015_1230_2.java : line 2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/ss_should_be_static/Code_8464822_8464808_2365_1.java : line 2 ==> Unread field: should this field be static? (PERFORMANCE)
# sample_sptbg/upm_uncalled_private_method/Code_53994118_53994091_1161_2.java : lines 1-9 ==> Private method is never called (PERFORMANCE)
# sample_sptbg/urf_unread_field/Code