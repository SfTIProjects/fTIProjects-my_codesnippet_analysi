# %%
import time
from datetime import timedelta

import html
import re

import os
import ntpath

import subprocess as sp

import numpy as np
import pandas as pd
import xml.etree.ElementTree as et

import dask
import dask.dataframe as dd
import dask.bag as bd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# %% [markdown]
# ## Read csv files Java Answers

# %%
df = dd.read_csv('checkstylexmlreports_csv/checkstyleReport*.csv', engine='python', error_bad_lines=False, warn_bad_lines=False, dtype=object)

# %% [markdown]
# ## Start a Dask cluster using SLURM jobs as workers

# %%
#http://jobqueue.dask.org/en/latest/generated/dask_jobqueue.SLURMCluster.html
dask.config.set(
    {
        "distributed.worker.memory.target": False,  # avoid spilling to disk
        "distributed.worker.memory.spill": False,  # avoid spilling to disk
    }
)
cluster = SLURMCluster(
    cores=2, #cores=24, # we set each job to have 1 Worker, each using 10 cores (threads) and 8 GB of memory
    processes=2,
    memory="8GiB",
    walltime="0-00:30",# walltime="0-00:50",
    log_directory="../dask/logs",  # folder for SLURM logs for each worker
    local_directory="../dask",  # folder for workers data
)
# Out:
# /opt/nesi/CS400_centos7_bdw/Python/3.9.5-gimkl-2020a/lib/python3.9/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36291 instead
#   warnings.warn(

# %% [markdown]
# Spawn between 20 to 100 workers and connect a client to be able use them.

# %%
#cluster.scale(n=20) # ask for 20 jobs or workers
# This also works with adaptive clusters. This automatically launches and kill workers based on load.
# we tell our cluster to autoscale between 10 and 20 workers depending on the load
cluster.adapt(minimum_jobs=10, maximum_jobs=200)
#cluster.adapt(maximum_jobs=20)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://192.168.94.140:44032' processes=0 threads=0, memory=0 B>

# %%
df
# Out:
# Dask DataFrame Structure:
#                    name    line severity message  source
# npartitions=101
#                  object  object   object  object  object
#                     ...     ...      ...     ...     ...
# ...                 ...     ...      ...     ...     ...
#                     ...     ...      ...     ...     ...
#                     ...     ...      ...     ...     ...
# Dask Name: read-csv, 101 tasks

# %%
checkstyle_codeviolations_init_len = df.shape[0].compute()
print('Initial number of volations {}'.format(checkstyle_codeviolations_init_len))
# Out:
# Initial number of volations 8074616

# %%
# drop empty columns
df = df[~df['name'].isna()] # Drop rows that have NaN in the Code column

# %%
checkstyle_codeviolations_nonan_len =df.shape[0].compute()
print('Number of violations after removing the nans in the class column {}'.format(checkstyle_codeviolations_nonan_len))
# Out:
# Number of violations after removing the nans in the class column 8074616

# %%
df.shape[0].compute()
# Out:
# 8074616

# %% [markdown]
# #### Get the unique classes dataframe

# %%
# get the unique classes
unique_classes_df = df['name'].drop_duplicates().compute()

# %%
# This also counts the unique classes
unique_classes_df.shape[0]
# Out:
# 731116

# %% [markdown]
# ### Get the unique Violations

# %%
grp_vio = df.groupby('source')

# %%
#count the unique rulesets
grp_vio.first().head()
# Out:
#                                                                                  name  \
# source
# com.puppycrawl.tools.checkstyle.checks.ArrayTyp...  Code_30381834_6434168_4179_3.java
# com.puppycrawl.tools.checkstyle.checks.FinalPar...  Code_30381834_6434168_4179_3.java
# com.puppycrawl.tools.checkstyle.checks.NewlineA...  Code_30381834_6434168_4179_3.java
# com.puppycrawl.tools.checkstyle.checks.TodoComm...  Code_47202560_47190189_667_0.java
# com.puppycrawl.tools.checkstyle.checks.UpperEll...  Code_54470504_54469628_699_1.java
#
#                                                    line severity  \
# source
# com.puppycrawl.tools.checkstyle.checks.ArrayTyp...    2    error
# com.puppycrawl.tools.checkstyle.checks.FinalPar...    2    error
# com.puppycrawl.tools.checkstyle.checks.NewlineA...    1    error
# com.puppycrawl.tools.checkstyle.checks.TodoComm...   76    error
# com.puppycrawl.tools.checkstyle.checks.UpperEll...    7    error
#
#                                                                                   message
# source
# com.puppycrawl.tools.checkstyle.checks.ArrayTyp...    Array brackets at illegal position.
# com.puppycrawl.tools.checkstyle.checks.FinalPar...        Parameter args should be final.
# com.puppycrawl.tools.checkstyle.checks.NewlineA...      File does not end with a newline.
# com.puppycrawl.tools.checkstyle.checks.TodoComm...  Comment matches to-do format 'TODO:'.
# com.puppycrawl.tools.checkstyle.checks.UpperEll...              Should use uppercase 'L'.

# %% [markdown]
# ### Count the number of times each items occured

# %%
#https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
viol_count_df = pd.DataFrame(df.groupby('source')['source'].count().compute())
# rename the column to total
viol_count_df.columns=['total']
# drop the index level
viol_count_df = viol_count_df.reset_index()
viol_count_df
# Out:
#                                                source    total
# 0   com.puppycrawl.tools.checkstyle.checks.ArrayTy...    28859
# 1   com.puppycrawl.tools.checkstyle.checks.FinalPa...   863887
# 2   com.puppycrawl.tools.checkstyle.checks.Newline...   484311
# 3   com.puppycrawl.tools.checkstyle.checks.TodoCom...     1870
# 4   com.puppycrawl.tools.checkstyle.checks.UpperEl...      807
# ..                                                ...      ...
# 56  com.puppycrawl.tools.checkstyle.checks.whitesp...   186132
# 57  com.puppycrawl.tools.checkstyle.checks.whitesp...      988
# 58  com.puppycrawl.tools.checkstyle.checks.whitesp...   414293
# 59  com.puppycrawl.tools.checkstyle.checks.whitesp...  1038215
# 60  com.puppycrawl.tools.checkstyle.checks.whitesp...        1
#
# [61 rows x 2 columns]

# %%
viol_count_df['percent'] = (viol_count_df['total']/ viol_count_df['total'].sum())*100

# %%
viol_count_df.head()
# Out:
#                                               source   total    percent
# 0  com.puppycrawl.tools.checkstyle.checks.ArrayTy...   28859   0.357404
# 1  com.puppycrawl.tools.checkstyle.checks.FinalPa...  863887  10.698800
# 2  com.puppycrawl.tools.checkstyle.checks.Newline...  484311   5.997945
# 3  com.puppycrawl.tools.checkstyle.checks.TodoCom...    1870   0.023159
# 4  com.puppycrawl.tools.checkstyle.checks.UpperEl...     807   0.009994

# %% [markdown]
# ### Calculate number to be sampled per ruleset

# %%
import math
def comp_smpl_no(x):
    x = round((x/100)*384)
    if x < 1:
        x = 1
    return x

# Randomly select that number
#https://datatofish.com/random-rows-pandas-dataframe/
#chk_style_ran = df.sample(frac=384/len(df), replace=None, random_state=10)
viol_count_df['sample_size_384'] = viol_count_df['percent'].apply(comp_smpl_no)
viol_count_df.head()
# Out:
#                                               source   total    percent  \
# 0  com.puppycrawl.tools.checkstyle.checks.ArrayTy...   28859   0.357404
# 1  com.puppycrawl.tools.checkstyle.checks.FinalPa...  863887  10.698800
# 2  com.puppycrawl.tools.checkstyle.checks.Newline...  484311   5.997945
# 3  com.puppycrawl.tools.checkstyle.checks.TodoCom...    1870   0.023159
# 4  com.puppycrawl.tools.checkstyle.checks.UpperEl...     807   0.009994
#
#    sample_size_384
# 0                1
# 1               41
# 2               23
# 3                1
# 4                1

# %% [markdown]
# ### Final Sample Used

# %%
viol_count_df['sample_size_384'].sum()
# Out:
# 409

# %% [markdown]
# ### Group by Source

# %%
grp_df = df.groupby('source')

# %%
grp_dfs = []

# %%
for vio, sample_size in zip(viol_count_df['source'], viol_count_df['sample_size_384']): # e.g., Best Practices, Coding Style, Design
    # get the last word after dots delemeter as well as convert to lower case
    subfolder = vio.lower().split('.')[-1]
    
    # Get all the values belonging to source violations, say ArrayType
    vio_grp = grp_df.get_group(vio)
    vio_grp = vio_grp.reset_index(drop=True).compute()
    #vio_grp.head()
    
    # Randomly select that number
    #https://datatofish.com/random-rows-pandas-dataframe/
    vio_grp_ran = vio_grp.sample(n=sample_size, random_state=10)
    # add the subfolder to get java file
    vio_grp_ran['sample_subfolder'] = subfolder
    # append the data frame to a list
    grp_dfs.append(vio_grp_ran)
    
    
    ## Make a folder in that directory
    folder = 'sample_ckstyl'
    # output: path/to/Post.csv => path/to
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    ## Make a folder in that directory
    folder = 'sample_ckstyl/{}'.format(subfolder)
    # output: path/to/Post.csv => path/to
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    # copy list of sample java files into the destination 
    for filename_to_copy in vio_grp_ran['name']:
        file_to_copy = '{}'.format(filename_to_copy)
        copy_file_cmd = 'cp codesnippets_java/{} {}'.format(file_to_copy, folder)
        cmd = sp.run(
            copy_file_cmd, # command
            capture_output=True,
            text=True,
            shell=True
        )

# %% [markdown]
# ### Observed Test

# %%
# Combine all the group dataframe
com_grp_dfs = pd.concat(grp_dfs)
com_grp_dfs.head()
# Out:
#                                    name line severity  \
# 245   Code_35861549_10647520_592_0.java    6    error
# 5866  Code_38850603_38849026_632_0.java   35    error
# 5316  Code_30712003_30711571_426_0.java   38    error
# 8192   Code_19237136_19236980_86_0.java    2    error
# 496    Code_11361395_3389264_537_3.java    2    error
#
#                                   message  \
# 245   Array brackets at illegal position.
# 5866         Parameter e should be final.
# 5316      Parameter args should be final.
# 8192         Parameter a should be final.
# 496     Parameter digits should be final.
#
#                                                  source      sample_subfolder
# 245   com.puppycrawl.tools.checkstyle.checks.ArrayTy...   arraytypestylecheck
# 5866  com.puppycrawl.tools.checkstyle.checks.FinalPa...  finalparameterscheck
# 5316  com.puppycrawl.tools.checkstyle.checks.FinalPa...  finalparameterscheck
# 8192  com.puppycrawl.tools.checkstyle.checks.FinalPa...  finalparameterscheck
# 496   com.puppycrawl.tools.checkstyle.checks.FinalPa...  finalparameterscheck

# %% [markdown]
# ### Sort them in order

# %%
#com_grp_dfs.sort_values('name', ascending=True, inplace=True)
com_grp_dfs.sort_values(['sample_subfolder', 'name'], ascending=[True, True], inplace=True)

# %%
com_grp_dfs.head()
# Out:
#                                    name line severity  \
# 245   Code_35861549_10647520_592_0.java    6    error
# 19    Code_35691321_35691064_861_0.java   13    error
# 178   Code_15724003_15723834_378_2.java    3    error
# 347  Code_26706024_26705991_1048_1.java    2    error
# 39   Code_50769992_50767941_1873_3.java    7    error
#
#                                                message  \
# 245                Array brackets at illegal position.
# 19                                Avoid nested blocks.
# 178  Using the '.*' form of import should be avoide...
# 347  Using the '.*' form of import should be avoide...
# 39   Name 'random' must match pattern '^[A-Z][A-Z0-...
#
#                                                 source        sample_subfolder
# 245  com.puppycrawl.tools.checkstyle.checks.ArrayTy...     arraytypestylecheck
# 19   com.puppycrawl.tools.checkstyle.checks.blocks....  avoidnestedblockscheck
# 178  com.puppycrawl.tools.checkstyle.checks.imports...    avoidstarimportcheck
# 347  com.puppycrawl.tools.checkstyle.checks.imports...    avoidstarimportcheck
# 39   com.puppycrawl.tools.checkstyle.checks.naming....       constantnamecheck

# %%
for subfol, name, ln, msg in zip(com_grp_dfs['sample_subfolder'], com_grp_dfs['name'], com_grp_dfs['line'], com_grp_dfs['message']):
    print('sample_ckstyl/{}/{} : line {} ==> {}'.format(subfol, name, ln, msg))
# Out:
# sample_ckstyl/arraytypestylecheck/Code_35861549_10647520_592_0.java : line 6 ==> Array brackets at illegal position.
# sample_ckstyl/avoidnestedblockscheck/Code_35691321_35691064_861_0.java : line 13 ==> Avoid nested blocks.
# sample_ckstyl/avoidstarimportcheck/Code_15724003_15723834_378_2.java : line 3 ==> Using the '.*' form of import should be avoided - java.awt.*.
# sample_ckstyl/avoidstarimportcheck/Code_26706024_26705991_1048_1.java : line 2 ==> Using the '.*' form of import should be avoided - javax.swing.*.
# sample_ckstyl/constantnamecheck/Code_50769992_50767941_1873_3.java : line 7 ==> Name 'random' must match pattern '^[A-Z][A-Z0-9]*(_[A-Z0-9]+)*$'.
# sample_ckstyl/designforextensioncheck/Code_10852320_10850563_23_0.java : line 5 ==> Class 'Code_10852320_10850563_23_0' looks like designed for extension (can be subclassed), but the method 'm1' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_10852320_10850563_23_0' final or making the method 'm1' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_11484412_11484169_142_2.java : line 28 ==> Class 'Code_11484412_11484169_142_2' looks like designed for extension (can be subclassed), but the method 'setValueTwo' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_11484412_11484169_142_2' final or making the method 'setValueTwo' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_12758844_12758641_448_0.java : line 10 ==> Class 'Wrap' looks like designed for extension (can be subclassed), but the method 'foo' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Wrap' final or making the method 'foo' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_22642582_22642231_5200_0.java : line 2 ==> Class 'Code_22642582_22642231_5200_0' looks like designed for extension (can be subclassed), but the method 'nodeCount' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_22642582_22642231_5200_0' final or making the method 'nodeCount' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_25478544_25478444_1611_0.java : line 8 ==> Class 'Code' looks like designed for extension (can be subclassed), but the method 'hh' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code' final or making the method 'hh' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_33131517_33131195_1752_4.java : line 6 ==> Class 'Code' looks like designed for extension (can be subclassed), but the method 'foo' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code' final or making the method 'foo' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_36160534_36159475_4986_0.java : line 3 ==> Class 'Code_36160534_36159475_4986_0' looks like designed for extension (can be subclassed), but the method 'decode' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_36160534_36159475_4986_0' final or making the method 'decode' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_41508231_25373053_1161_3.java : line 16 ==> Class 'Code_41508231_25373053_1161_3' looks like designed for extension (can be subclassed), but the method 'login' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_41508231_25373053_1161_3' final or making the method 'login' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_45519573_45519444_411_1.java : line 83 ==> Class 'Code_45519573_45519444_411_1' looks like designed for extension (can be subclassed), but the method 'setSignature' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_45519573_45519444_411_1' final or making the method 'setSignature' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_47642581_47640647_732_0.java : line 2 ==> Class 'Code_47642581_47640647_732_0' looks like designed for extension (can be subclassed), but the method 'lock' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_47642581_47640647_732_0' final or making the method 'lock' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_51988772_51974505_885_0.java : line 29 ==> Class 'Clf010Processor' looks like designed for extension (can be subclassed), but the method 'process' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Clf010Processor' final or making the method 'process' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_53981922_53980769_77_0.java : line 27 ==> Class 'Code_53981922_53980769_77_0' looks like designed for extension (can be subclassed), but the method 'removeChangeListener' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_53981922_53980769_77_0' final or making the method 'removeChangeListener' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_55843951_49633672_1716_2.java : line 4 ==> Class 'Code_55843951_49633672_1716_2' looks like designed for extension (can be subclassed), but the method 'mergePasswordAndSalt' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_55843951_49633672_1716_2' final or making the method 'mergePasswordAndSalt' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_61578377_61577584_1978_3.java : line 9 ==> Class 'Code_61578377_61577584_1978_3' looks like designed for extension (can be subclassed), but the method 'displayName' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_61578377_61577584_1978_3' final or making the method 'displayName' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_7042627_7040279_227_2.java : line 6 ==> Class 'Code_7042627_7040279_227_2' looks like designed for extension (can be subclassed), but the method 'setUser' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_7042627_7040279_227_2' final or making the method 'setUser' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/designforextensioncheck/Code_7205491_7205408_3393_0.java : line 2 ==> Class 'Code_7205491_7205408_3393_0' looks like designed for extension (can be subclassed), but the method 'primeTest' does not have javadoc that explains how to do that safely. If class is not designed for extension consider making the class 'Code_7205491_7205408_3393_0' final or making the method 'primeTest' static/final/abstract/empty, or adding allowed annotation for the method.
# sample_ckstyl/emptyblockcheck/Code_5201528_5201228_3633_1.java : line 28 ==> Must have at least one statement.
# sample_ckstyl/emptyforiteratorpadcheck/Code_59696662_59696611_3240_4.java : line 4 ==> ';' is followed by whitespace.
# sample_ckstyl/emptystatementcheck/Code_66083973_66083612_1593_0.java : line 21 ==> Empty statement.
# sample_ckstyl/equalshashcodecheck/Code_64631318_64630536_117_1.java : line 2 ==> Definition of 'equals()' without corresponding definition of 'hashCode()'.
# sample_ckstyl/filetabcharactercheck/Code_68258512_68258347_958_4.java : line 2 ==> File contains tab characters (this is the first instance).
# sample_ckstyl/finalclasscheck/Code_47275715_32105167_3728_0.java : line 1 ==> Class Code_47275715_32105167_3728_0 should be declared as final.
# sample_ckstyl/finalparameterscheck/Code_11361395_3389264_537_3.java : line 2 ==> Parameter digits should be final.
# sample_ckstyl/finalparameterscheck/Code_12866173_12848566_2293_0.java : line 70 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_16497112_16497035_2680_2.java : line 9 ==> Parameter v should be final.
# sample_ckstyl/finalparameterscheck/Code_16934526_16928069_375_1.java : line 2 ==> Parameter mediaPlayer should be final.
# sample_ckstyl/finalparameterscheck/Code_19115872_19111680_696_0.java : line 5 ==> Parameter object should be final.
# sample_ckstyl/finalparameterscheck/Code_19237136_19236980_86_0.java : line 2 ==> Parameter a should be final.
# sample_ckstyl/finalparameterscheck/Code_20335334_20335102_5190_0.java : line 8 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_20649023_20648983_5709_1.java : line 2 ==> Parameter context should be final.
# sample_ckstyl/finalparameterscheck/Code_27368269_10118765_4382_0.java : line 23 ==> Parameter hours should be final.
# sample_ckstyl/finalparameterscheck/Code_28936354_28935849_180_0.java : line 16 ==> Parameter arr should be final.
# sample_ckstyl/finalparameterscheck/Code_30712003_30711571_426_0.java : line 38 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_31284973_31283344_1188_4.java : line 3 ==> Parameter activity should be final.
# sample_ckstyl/finalparameterscheck/Code_31886335_31885318_2529_7.java : line 27 ==> Parameter value should be final.
# sample_ckstyl/finalparameterscheck/Code_32494048_32493946_1668_0.java : line 12 ==> Parameter ch should be final.
# sample_ckstyl/finalparameterscheck/Code_35439477_35438034_1000_0.java : line 6 ==> Parameter userIdToAdd should be final.
# sample_ckstyl/finalparameterscheck/Code_35552075_35551257_3191_1.java : line 2 ==> Parameter selectedDate should be final.
# sample_ckstyl/finalparameterscheck/Code_36245413_36244782_1893_10.java : line 39 ==> Parameter key2 should be final.
# sample_ckstyl/finalparameterscheck/Code_37204017_37203139_4802_0.java : line 161 ==> Parameter optionName should be final.
# sample_ckstyl/finalparameterscheck/Code_37258974_37233738_488_1.java : line 33 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_38850603_38849026_632_0.java : line 35 ==> Parameter e should be final.
# sample_ckstyl/finalparameterscheck/Code_40105621_40105449_106_0.java : line 10 ==> Parameter n should be final.
# sample_ckstyl/finalparameterscheck/Code_41896836_41896621_195_1.java : line 6 ==> Parameter savedInstanceState should be final.
# sample_ckstyl/finalparameterscheck/Code_45156281_42691392_2953_0.java : line 26 ==> Parameter beanClass should be final.
# sample_ckstyl/finalparameterscheck/Code_45810563_45803958_971_1.java : line 18 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_47644074_47643298_280_0.java : line 41 ==> Parameter observable should be final.
# sample_ckstyl/finalparameterscheck/Code_50236047_49727551_404_5.java : line 25 ==> Parameter response should be final.
# sample_ckstyl/finalparameterscheck/Code_50764407_50764302_586_6.java : line 2 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_5317588_5317443_199_0.java : line 6 ==> Parameter args should be final.
# sample_ckstyl/finalparameterscheck/Code_55548967_55548806_142_0.java : line 14 ==> Parameter primaryStage should be final.
# sample_ckstyl/finalparameterscheck/Code_57217544_38171022_3832_0.java : line 43 ==> Parameter delegate should be final.
# sample_ckstyl/finalparameterscheck/Code_57520094_57518208_705_10.java : line 2 ==> Parameter matrix should be final.
# sample_ckstyl/finalparameterscheck/Code_57959060_57958864_814_1.java : line 4 ==> Parameter sort should be final.
# sample_ckstyl/finalparameterscheck/Code_60213198_60125318_40_0.java : line 10 ==> Parameter savedInstanceState should be final.
# sample_ckstyl/finalparameterscheck/Code_61862353_61861876_2482_0.java : line 25 ==> Parameter status should be final.
# sample_ckstyl/finalparameterscheck/Code_64073951_48039876_2391_0.java : line 6 ==> Parameter request should be final.
# sample_ckstyl/finalparameterscheck/Code_65844919_30917782_1321_1.java : line 5 ==> Parameter status should be final.
# sample_ckstyl/finalparameterscheck/Code_66712480_66645283_944_2.java : line 2 ==> Parameter arrays should be final.
# sample_ckstyl/finalparameterscheck/Code_67072449_6198986_3101_0.java : line 2 ==> Parameter text should be final.
# sample_ckstyl/finalparameterscheck/Code_7520468_7520313_1335_1.java : line 2 ==> Parameter val should be final.
# sample_ckstyl/finalparameterscheck/Code_8233659_8233623_3251_0.java : line 5 ==> Parameter len should be final.
# sample_ckstyl/finalparameterscheck/Code_8590490_8590435_4010_0.java : line 2 ==> Parameter l should be final.
# sample_ckstyl/genericwhitespacecheck/Code_27805039_27804526_872_0.java : line 2 ==> '>' is followed by an illegal character.
# sample_ckstyl/hiddenfieldcheck/Code_13548815_13547004_1878_0.java : line 83 ==> 'latitude' hides a field.
# sample_ckstyl/hiddenfieldcheck/Code_14650218_14649819_1803_1.java : line 5 ==> 'data' hides a field.
# sample_ckstyl/hiddenfieldcheck/Code_31359401_31357794_1642_1.java : line 88 ==> 'y' hides a field.
# sample_ckstyl/hiddenfieldcheck/Code_34724281_34722520_655_3.java : line 7 ==> 'payload' hides a field.
# sample_ckstyl/hiddenfieldcheck/Code_41849201_41837063_3710_0.java : line 21 ==> 'project' hides a field.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_17969885_17969729_2352_0.java : line 1 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_22413406_22413347_91_0.java : line 1 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_25268770_25260478_601_3.java : line 1 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_27527876_27527436_946_0.java : line 9 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_28391152_3255051_2282_0.java : line 1 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_29409232_2116870_598_1.java : line 26 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/hideutilityclassconstructorcheck/Code_5641058_5640850_2507_0.java : line 1 ==> Utility classes should not have a public or default constructor.
# sample_ckstyl/illegalimportcheck/Code_55707733_55698109_406_5.java : line 5 ==> Illegal import - sun.jvm.hotspot.tools.Tool.
# sample_ckstyl/innerassignmentcheck/Code_7154564_7154534_1123_2.java : line 37 ==> Inner assignments should be avoided.
# sample_ckstyl/interfaceistypecheck/Code_59841957_26188410_1346_2.java : line 3 ==> interfaces should describe a type and hence have methods.
# sample_ckstyl/invalidjavadocpositioncheck/Code_36898639_36898485_4015_0.java : line 1 ==> Javadoc comment is placed in the wrong location.
# sample_ckstyl/javadocmethodcheck/Code_10846622_10813676_3992_0.java : line 313 ==> Expected @param tag for 'weekNumber'.
# sample_ckstyl/javadocpackagecheck/Code_64191591_64190234_135_4.java : line 1 ==> Missing package-info.java file.
# sample_ckstyl/javadocstylecheck/Code_8504700_8496155_2620_0.java : line 16 ==> First sentence should end with a period.
# sample_ckstyl/javadoctypecheck/Code_40095161_40068965_578_4.java : line 30 ==> Type Javadoc comment is missing @param <T> tag.
# sample_ckstyl/javadocvariablecheck/Code_10121046_3946102_2861_1.java : line 9 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_13324301_9251940_361_0.java : line 15 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_16462024_16461555_2262_0.java : line 14 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_16582096_16321172_16_1.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_16786120_16785982_3141_5.java : line 54 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_170371_169420_3410_0.java : line 25 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_20052179_20052129_925_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_21880926_21880467_662_0.java : line 8 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_24487137_24487067_1006_3.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_26803928_20387881_1947_0.java : line 5 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_27485059_27484413_185_0.java : line 6 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_2945336_2945309_554_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_31356935_31356807_1613_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_34518476_34518019_917_1.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_37081280_36900630_662_9.java : line 5 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_39237947_39237835_1819_7.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_39490267_39488721_3349_0.java : line 4 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_42494997_36434521_414_12.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_44116101_17293914_1280_0.java : line 7 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_46527948_46527790_4349_0.java : line 14 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_46857874_46857623_556_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_48223451_48220613_2030_1.java : line 8 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_51825034_51824854_2196_2.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_56904861_56903483_635_5.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_5713495_3926519_747_2.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_57801432_57799193_1312_3.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_58960445_58923054_4406_0.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_59945830_59818479_3334_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_6160230_6144036_1294_1.java : line 172 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_61697755_61697526_542_1.java : line 18 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_64122582_64062614_3204_0.java : line 5 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_68189606_68189139_3241_2.java : line 5 ==> Missing a Javadoc comment.
# sample_ckstyl/javadocvariablecheck/Code_9784904_9784744_3060_0.java : line 4 ==> Missing a Javadoc comment.
# sample_ckstyl/leftcurlycheck/Code_12301173_12266196_1732_0.java : line 148 ==> '{' at column 9 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_14945777_14945656_44_0.java : line 4 ==> '{' at column 1 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_18336779_18335746_4697_0.java : line 5 ==> '{' at column 5 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_18403738_18403137_3182_1.java : line 28 ==> '{' at column 9 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_19473492_19473268_5105_0.java : line 64 ==> '{' at column 8 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_19569639_19568556_1773_0.java : line 133 ==> '{' at column 5 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_20708617_14219276_464_1.java : line 301 ==> '{' at column 5 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_33087779_33074578_439_5.java : line 41 ==> '{' at column 5 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_51730589_38211849_761_0.java : line 41 ==> '{' at column 13 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_58463361_40001816_5134_2.java : line 4 ==> '{' at column 9 should be on the previous line.
# sample_ckstyl/leftcurlycheck/Code_9537334_9521342_3727_1.java : line 4 ==> '{' at column 1 should be on the previous line.
# sample_ckstyl/linelengthcheck/Code_12252237_12251962_1175_0.java : line 9 ==> Line is longer than 80 characters (found 82).
# sample_ckstyl/linelengthcheck/Code_21796048_21796022_5316_0.java : line 2 ==> Line is longer than 80 characters (found 81).
# sample_ckstyl/linelengthcheck/Code_23197256_4528016_444_0.java : line 25 ==> Line is longer than 80 characters (found 82).
# sample_ckstyl/linelengthcheck/Code_24485333_24411436_1891_2.java : line 3 ==> Line is longer than 80 characters (found 153).
# sample_ckstyl/linelengthcheck/Code_30196496_30195185_513_1.java : line 21 ==> Line is longer than 80 characters (found 111).
# sample_ckstyl/linelengthcheck/Code_31295818_31291815_958_0.java : line 3 ==> Line is longer than 80 characters (found 116).
# sample_ckstyl/linelengthcheck/Code_32638014_15876427_1248_0.java : line 4 ==> Line is longer than 80 characters (found 118).
# sample_ckstyl/linelengthcheck/Code_35275557_34718586_1796_3.java : line 7 ==> Line is longer than 80 characters (found 86).
# sample_ckstyl/linelengthcheck/Code_35857484_35857108_4229_0.java : line 3 ==> Line is longer than 80 characters (found 427).
# sample_ckstyl/linelengthcheck/Code_36177311_36174983_38_1.java : line 10 ==> Line is longer than 80 characters (found 128).
# sample_ckstyl/linelengthcheck/Code_37507893_37507527_635_2.java : line 88 ==> Line is longer than 80 characters (found 103).
# sample_ckstyl/linelengthcheck/Code_40548662_40548464_3550_1.java : line 4 ==> Line is longer than 80 characters (found 102).
# sample_ckstyl/linelengthcheck/Code_44462351_44460769_11_0.java : line 2 ==> Line is longer than 80 characters (found 136).
# sample_ckstyl/linelengthcheck/Code_47606164_47132064_136_1.java : line 19 ==> Line is longer than 80 characters (found 94).
# sample_ckstyl/linelengthcheck/Code_52478019_52475731_713_3.java : line 31 ==> Line is longer than 80 characters (found 82).
# sample_ckstyl/linelengthcheck/Code_53445321_53445088_3884_0.java : line 2 ==> Line is longer than 80 characters (found 107).
# sample_ckstyl/linelengthcheck/Code_54993907_54993243_308_6.java : line 31 ==> Line is longer than 80 characters (found 115).
# sample_ckstyl/linelengthcheck/Code_55396799_55376094_1075_8.java : line 4 ==> Line is longer than 80 characters (found 141).
# sample_ckstyl/linelengthcheck/Code_55837516_55837220_1621_3.java : line 2 ==> Line is longer than 80 characters (found 91).
# sample_ckstyl/linelengthcheck/Code_58131379_58114283_2495_1.java : line 30 ==> Line is longer than 80 characters (found 82).
# sample_ckstyl/linelengthcheck/Code_60029957_60029077_570_2.java : line 9 ==> Line is longer than 80 characters (found 90).
# sample_ckstyl/linelengthcheck/Code_61269613_19673962_1010_0.java : line 85 ==> Line is longer than 80 characters (found 82).
# sample_ckstyl/linelengthcheck/Code_65209728_65206866_1894_2.java : line 14 ==> Line is longer than 80 characters (found 115).
# sample_ckstyl/localfinalvariablenamecheck/Code_14422099_14422025_2066_2.java : line 262 ==> Name 'TMP_COLOR' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/localvariablenamecheck/Code_29052070_29047793_285_0.java : line 57 ==> Name 'byte_array_4' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/magicnumbercheck/Code_10119271_10118029_1694_2.java : line 8 ==> '-3' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_12666531_7119472_2438_14.java : line 6 ==> '73' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_14434242_14434062_3705_3.java : line 4 ==> '4' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_17569019_17568588_1164_0.java : line 4 ==> '5' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_19433032_19431689_772_0.java : line 17 ==> '15' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_20835551_20825640_3075_1.java : line 3 ==> '10' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_22458176_22458042_186_0.java : line 14 ==> '1000' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_26011661_26010906_1409_12.java : line 56 ==> '95' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_26375322_26375128_652_0.java : line 6 ==> '6' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_28224544_176137_2457_0.java : line 77 ==> '10000000' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_28843995_28843703_137_5.java : line 58 ==> '50' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_30553979_30552644_809_7.java : line 49 ==> '0.941' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_31061760_31061457_623_1.java : line 63 ==> '5' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_39198383_39197923_1598_1.java : line 15 ==> '96' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_39628094_39627984_1180_1.java : line 4 ==> '550' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_39887597_39887113_1145_0.java : line 25 ==> '7' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_42305369_42305269_738_0.java : line 6 ==> '10' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_4265472_469695_140_0.java : line 50 ==> '3' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_43927027_43926154_4578_0.java : line 48 ==> '10' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_44315611_10370508_1986_0.java : line 12 ==> '1900' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_47808902_47808186_4140_0.java : line 11 ==> '12' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_50401104_50401012_565_2.java : line 14 ==> '2000' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_52861226_52861114_2843_0.java : line 3 ==> '100' is a magic number.
# sample_ckstyl/magicnumbercheck/Code_64669766_64669144_756_1.java : line 21 ==> '123L' is a magic number.
# sample_ckstyl/membernamecheck/Code_51845612_51845411_2499_0.java : line 6 ==> Name 'EditText1' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/methodlengthcheck/Code_58993471_58993036_78_1.java : line 12 ==> Method main length is 164 lines (max allowed is 150).
# sample_ckstyl/methodnamecheck/Code_21427297_11602271_1346_1.java : line 76 ==> Name 'LOGI' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/methodparampadcheck/Code_12687016_12686979_3806_0.java : line 3 ==> '(' is preceded with whitespace.
# sample_ckstyl/methodparampadcheck/Code_40456778_40456276_1054_0.java : line 62 ==> '(' is preceded with whitespace.
# sample_ckstyl/missingjavadocmethodcheck/Code_11296702_11296542_1615_1.java : line 14 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_11861497_11842086_724_0.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_21327517_2802775_860_0.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_21966029_21965828_2547_3.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_22590501_22562867_1724_0.java : line 7 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_24048324_24039472_4326_4.java : line 23 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_24776238_24770796_2226_4.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_32003278_32002994_4686_1.java : line 18 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_37196775_37196461_126_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_37241994_37241306_489_7.java : line 10 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_37547569_37547399_336_0.java : line 10 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_3775723_3775694_1391_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_41069085_40887313_3675_0.java : line 14 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_4283867_4283304_2811_6.java : line 16 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_43275686_43275603_1246_0.java : line 14 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_43970238_43970181_257_0.java : line 3 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_46678915_46678810_2571_2.java : line 16 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_48836170_48835996_3655_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_53872220_53872070_2323_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_54729560_9365619_71_0.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_60069014_60068989_1521_1.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_62192006_25526833_3584_0.java : line 63 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_64063046_64060492_519_6.java : line 48 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_64577603_49190827_2993_0.java : line 10 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_67495525_67494536_30_3.java : line 82 ==> Missing a Javadoc comment.
# sample_ckstyl/missingjavadocmethodcheck/Code_9901610_9901552_2274_10.java : line 2 ==> Missing a Javadoc comment.
# sample_ckstyl/missingswitchdefaultcheck/Code_35495855_34342816_2055_1.java : line 33 ==> switch without "default" clause.
# sample_ckstyl/modifierordercheck/Code_33827612_2701817_4824_0.java : line 161 ==> 'private' modifier out of order with the JLS suggestions.
# sample_ckstyl/multiplevariabledeclarationscheck/Code_4182068_4181941_2088_0.java : line 8 ==> Each variable declaration must be in its own statement.
# sample_ckstyl/needbracescheck/Code_26346384_26346164_53_9.java : line 21 ==> 'else' construct must use '{}'s.
# sample_ckstyl/needbracescheck/Code_26416371_26408277_892_1.java : line 60 ==> 'if' construct must use '{}'s.
# sample_ckstyl/needbracescheck/Code_31247699_31246088_1301_0.java : line 3 ==> 'if' construct must use '{}'s.
# sample_ckstyl/needbracescheck/Code_45113244_45112876_262_0.java : line 26 ==> 'else' construct must use '{}'s.
# sample_ckstyl/needbracescheck/Code_53969219_27878888_3927_0.java : line 7 ==> 'if' construct must use '{}'s.
# sample_ckstyl/newlineatendoffilecheck/Code_11907398_11907273_1815_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_17801532_17801407_477_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_17829806_17829577_970_2.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_19573237_19573184_339_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_20173779_20173657_1520_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_30262201_30261143_1330_2.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_30547336_30546826_1542_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_3245407_3245331_745_6.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_36922203_36908027_4441_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_40720750_40720715_2110_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_43888688_43888546_3832_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_44476271_44476109_251_4.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_48447275_48447206_1470_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_51609468_19235606_841_5.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_58875379_58874482_225_6.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_5929216_5192562_19_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_59950518_59950428_826_6.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_60635859_40657096_3245_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_6319313_6319163_3931_1.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_64578185_64577506_3004_2.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_64912592_64774526_192_1.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_7378374_7378351_1000_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/newlineatendoffilecheck/Code_785708_785618_2117_0.java : line 1 ==> File does not end with a newline.
# sample_ckstyl/nowhitespaceaftercheck/Code_2088078_2087198_4768_0.java : line 19 ==> '{' is followed by whitespace.
# sample_ckstyl/nowhitespaceaftercheck/Code_33439150_33438697_2389_0.java : line 5 ==> '{' is followed by whitespace.
# sample_ckstyl/nowhitespacebeforecheck/Code_30784998_30784008_1813_6.java : line 15 ==> ';' is preceded with whitespace.
# sample_ckstyl/nowhitespacebeforecheck/Code_5308046_5307992_15_0.java : line 12 ==> ';' is preceded with whitespace.
# sample_ckstyl/operatorwrapcheck/Code_37087606_37087199_1454_2.java : line 6 ==> ':' should be on a new line.
# sample_ckstyl/packagenamecheck/Code_1655616_1655596_1230_0.java : line 1 ==> Name 'simulated_anealing' must match pattern '^[a-z]+(\.[a-zA-Z_][a-zA-Z0-9_]*)*$'.
# sample_ckstyl/parameternamecheck/Code_19468317_19468278_4990_1.java : line 27 ==> Name 'Mobilecheckcharge' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/parameternumbercheck/Code_46024058_46023983_139_2.java : line 9 ==> More than 7 parameters (found 8).
# sample_ckstyl/parenpadcheck/Code_10050561_10050498_2194_0.java : line 4 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_41240612_40996942_1908_0.java : line 2 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_46391614_46390898_2024_4.java : line 2 ==> '(' is followed by whitespace.
# sample_ckstyl/parenpadcheck/Code_46569901_46568535_676_2.java : line 11 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_5373182_5372279_1654_0.java : line 58 ==> '(' is followed by whitespace.
# sample_ckstyl/parenpadcheck/Code_55260386_55238118_270_2.java : line 4 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_55649575_55649218_309_0.java : line 4 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_6802331_6799171_931_0.java : line 33 ==> ')' is preceded with whitespace.
# sample_ckstyl/parenpadcheck/Code_68449830_68442742_435_14.java : line 4 ==> ')' is preceded with whitespace.
# sample_ckstyl/redundantimportcheck/Code_40710127_40710057_161_0.java : line 2 ==> Redundant import from the java.lang package - java.lang.Object.
# sample_ckstyl/redundantmodifiercheck/Code_12548428_12548394_1146_1.java : line 13 ==> Redundant 'public' modifier.
# sample_ckstyl/redundantmodifiercheck/Code_30328338_30328222_2146_0.java : line 39 ==> Redundant 'public' modifier.
# sample_ckstyl/regexpsinglelinecheck/Code_16624059_16555343_500_0.java : line 13 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_16975336_16975323_1483_1.java : line 9 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_1856856_1856440_1883_0.java : line 2 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_24650999_139076_2077_0.java : line 37 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_50644131_39094927_363_0.java : line 16 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_51559635_51559277_2065_3.java : line 15 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_52617694_52608204_2898_0.java : line 3 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_55593630_55593083_1660_0.java : line 8 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_61429664_11823095_3770_0.java : line 35 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_63382283_5818057_2847_0.java : line 8 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_63434385_63434244_3699_0.java : line 32 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_66487346_66448581_200_3.java : line 25 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_6847818_6846882_562_5.java : line 10 ==> Line has trailing spaces.
# sample_ckstyl/regexpsinglelinecheck/Code_8656655_4014948_170_0.java : line 32 ==> Line has trailing spaces.
# sample_ckstyl/rightcurlycheck/Code_10477934_10477825_3272_3.java : line 55 ==> '}' at column 13 should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks: if/else-if/else, do/while or try/catch/finally).
# sample_ckstyl/rightcurlycheck/Code_58585804_58585734_1868_0.java : line 34 ==> '}' at column 9 should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks: if/else-if/else, do/while or try/catch/finally).
# sample_ckstyl/simplifybooleanexpressioncheck/Code_35480496_35129670_1112_4.java : line 65 ==> Expression can be simplified.
# sample_ckstyl/simplifybooleanreturncheck/Code_39243958_39243837_914_0.java : line 27 ==> Conditional logic can be removed.
# sample_ckstyl/staticvariablenamecheck/Code_36888549_36884050_1068_2.java : line 4 ==> Name 'REPEAT_NOTIFICATION2' must match pattern '^[a-z][a-zA-Z0-9]*$'.
# sample_ckstyl/todocommentcheck/Code_56116351_56096141_1999_1.java : line 14 ==> Comment matches to-do format 'TODO:'.
# sample_ckstyl/typecastparenpadcheck/Code_58966417_58962911_4486_0.java : line 63 ==> ')' is preceded with whitespace.
# sample_ckstyl/typenamecheck/Code_10226102_10226002_1512_0.java : line 1 ==> Name 'Code_10226102_10226002_1512_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_10882230_10881998_412_0.java : line 1 ==> Name 'Code_10882230_10881998_412_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_11041210_11001458_2246_1.java : line 5 ==> Name 'Code_11041210_11001458_2246_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_11342511_11342400_3376_0.java : line 10 ==> Name 'Code_11342511_11342400_3376_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_11978332_11977119_3321_1.java : line 1 ==> Name 'Code_11978332_11977119_3321_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_1307676_1307477_2859_2.java : line 1 ==> Name 'Code_1307676_1307477_2859_2' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_15329608_15329579_1584_0.java : line 1 ==> Name 'Code_15329608_15329579_1584_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_19351595_19351573_475_1.java : line 1 ==> Name 'Code_19351595_19351573_475_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_2031785_2031768_2549_5.java : line 1 ==> Name 'Code_2031785_2031768_2549_5' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_21944585_21944202_151_0.java : line 3 ==> Name 'Code_21944585_21944202_151_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_22155235_22154456_517_5.java : line 16 ==> Name 'Code_22155235_22154456_517_5' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_25792679_25792166_227_0.java : line 1 ==> Name 'Code_25792679_25792166_227_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_26791300_26791184_3663_0.java : line 1 ==> Name 'Code_26791300_26791184_3663_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_29203966_29203920_677_5.java : line 1 ==> Name 'Code_29203966_29203920_677_5' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_30520429_30520300_1203_2.java : line 1 ==> Name 'Code_30520429_30520300_1203_2' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_31326912_31326784_316_2.java : line 1 ==> Name 'Code_31326912_31326784_316_2' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_34624354_34624224_254_0.java : line 1 ==> Name 'Code_34624354_34624224_254_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_35473278_35473009_1046_0.java : line 1 ==> Name 'Code_35473278_35473009_1046_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_36505603_36505302_1458_0.java : line 1 ==> Name 'Code_36505603_36505302_1458_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_40572768_40572204_4018_3.java : line 1 ==> Name 'Code_40572768_40572204_4018_3' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_45782789_45782593_308_2.java : line 1 ==> Name 'Code_45782789_45782593_308_2' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_45855543_45847021_638_2.java : line 1 ==> Name 'Code_45855543_45847021_638_2' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_46738964_46738348_3639_0.java : line 3 ==> Name 'Code_46738964_46738348_3639_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_48019634_48019289_1153_0.java : line 1 ==> Name 'Code_48019634_48019289_1153_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_48718459_48714322_434_12.java : line 1 ==> Name 'Code_48718459_48714322_434_12' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_54333746_54333650_1730_4.java : line 1 ==> Name 'Code_54333746_54333650_1730_4' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_55439557_55439144_3516_0.java : line 1 ==> Name 'Code_55439557_55439144_3516_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_5567818_5567322_2657_1.java : line 1 ==> Name 'Code_5567818_5567322_2657_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_5732142_5732058_245_0.java : line 1 ==> Name 'Code_5732142_5732058_245_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_58444265_8713557_4757_1.java : line 1 ==> Name 'Code_58444265_8713557_4757_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_59035440_21800032_929_0.java : line 1 ==> Name 'Code_59035440_21800032_929_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_60545818_60545563_467_1.java : line 1 ==> Name 'Code_60545818_60545563_467_1' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_63843305_63843071_375_8.java : line 1 ==> Name 'Code_63843305_63843071_375_8' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/typenamecheck/Code_9696788_9696069_1572_0.java : line 1 ==> Name 'Code_9696788_9696069_1572_0' must match pattern '^[A-Z][a-zA-Z0-9]*$'.
# sample_ckstyl/unusedimportscheck/Code_38642951_38597993_2141_0.java : line 2 ==> Unused import - java.util.Arrays.
# sample_ckstyl/upperellcheck/Code_19413603_19410357_1253_4.java : line 7 ==> Should use uppercase 'L'.
# sample_ckstyl/visibilitymodifiercheck/Code_13630352_13630276_366_0.java : line 2 ==> Variable 's' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_14810481_14807095_60_6.java : line 71 ==> Variable 'frame' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_19701349_19701305_1470_8.java : line 2 ==> Variable 'b' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_21199856_21199832_4463_3.java : line 2 ==> Variable 'decision4' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_21743455_21715533_4171_3.java : line 9 ==> Variable 'yValue' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_22157654_22156567_963_0.java : line 2 ==> Variable 'cookies' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_23144677_23140715_2391_2.java : line 10 ==> Variable 'response' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_25508741_20570481_38_0.java : line 3 ==> Variable 'fieldToTest' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_25609010_25608925_2533_1.java : line 2 ==> Variable 'regex' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_29276027_29275991_3942_1.java : line 2 ==> Variable 'p' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_32095877_32095830_497_2.java : line 2 ==> Variable 'meAsDog' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_33540153_33539387_1325_0.java : line 3 ==> Variable 'tvOne' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_33637336_33637178_1158_0.java : line 24 ==> Variable 'entities' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_35118428_35118383_4569_1.java : line 2 ==> Variable 'resultBMI' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_40602962_40602815_11_1.java : line 7 ==> Variable 'ar1' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_42125649_42125113_318_1.java : line 6 ==> Variable 'list' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_4399567_4396167_1319_0.java : line 4 ==> Variable 'logger' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_46892536_46892042_400_1.java : line 5 ==> Variable 'NOTIFICATION' must be private and have accessor methods.
# sample_ckstyl/visibilitymodifiercheck/Code_7409840_7409783_1062_2.java : line 6 ==> Variable 'myDBL2' must be private and have accessor methods.
# sample_ckstyl/whitespaceaftercheck/Code_13763940_3045482_2307_0.java : line 24 ==> ';' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_14604022_14603334_688_1.java : line 28 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_16176595_16113313_3158_8.java : line 74 ==> 'if' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_19781155_19781039_5640_0.java : line 62 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_22058807_22058594_5003_0.java : line 4 ==> 'if' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_22148744_22148668_1026_2.java : line 2 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_24969412_16213942_170_0.java : line 39 ==> 'if' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_27597568_27597380_466_2.java : line 48 ==> 'typecast' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_28614411_28613443_783_4.java : line 6 ==> 'if' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_30429987_30429821_99_1.java : line 10 ==> 'if' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_33194616_16707816_2644_1.java : line 35 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_38144644_38143938_1098_0.java : line 33 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_55928008_45476645_3040_0.java : line 2 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_56354992_8545590_1913_0.java : line 7 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_57895628_57895421_583_3.java : line 13 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_58062796_57991065_1068_0.java : line 44 ==> 'for' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_61703670_61703479_4092_0.java : line 23 ==> 'else' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_67399539_67384351_1228_15.java : line 29 ==> 'typecast' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_8016607_8016480_61_1.java : line 28 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespaceaftercheck/Code_9062940_9062079_1229_3.java : line 3 ==> ',' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_10648577_3718148_1563_4.java : line 9 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_14169974_14167814_4327_0.java : line 30 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_15105272_14887704_155_0.java : line 117 ==> '&&' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_15965522_15965164_4922_1.java : line 20 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_18297883_18297732_4061_0.java : line 34 ==> '{' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_19532488_13756235_105_0.java : line 31 ==> '}' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_19905744_19896562_2814_1.java : line 66 ==> '/' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_21275501_21274862_339_0.java : line 18 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_22630835_22626713_813_4.java : line 27 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_23587501_23587078_1003_0.java : line 25 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_23818886_23818199_0_0.java : line 15 ==> '-' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_23916016_23903575_1198_0.java : line 20 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_25109067_25107860_3089_0.java : line 10 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_28736925_28736419_1129_0.java : line 30 ==> '+' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_29073121_29007989_5310_0.java : line 12 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_3146912_3144315_4243_1.java : line 8 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_31597394_31597288_652_5.java : line 2 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_32029639_32029382_363_0.java : line 8 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_32470838_32459683_2345_4.java : line 4 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_33088460_33088388_702_0.java : line 4 ==> '*' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_33460710_33460478_470_5.java : line 11 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_33720104_33719607_1710_0.java : line 14 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_33967683_33944939_2632_0.java : line 25 ==> '=' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_36950884_36867632_4991_4.java : line 4 ==> '+' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_40580497_40579839_4190_0.java : line 26 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_41532356_41517572_706_1.java : line 2 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_41731150_41730800_1737_2.java : line 17 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_43012457_43011837_208_0.java : line 24 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_43430137_43429315_4719_13.java : line 125 ==> '=' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_4536080_4536068_3954_0.java : line 10 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_47573581_47573260_487_0.java : line 18 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_47648757_47644815_1415_0.java : line 43 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_49463768_49463242_1336_2.java : line 26 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_49869396_49869147_3887_2.java : line 10 ==> '==' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_53322291_53321296_998_1.java : line 2 ==> '=' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_5552659_5547993_3644_0.java : line 54 ==> '{' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_55736127_16671143_97_1.java : line 37 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_60265161_59912629_1050_3.java : line 179 ==> '-' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_61156402_61098081_3603_0.java : line 40 ==> '{' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_61998589_61996595_470_1.java : line 91 ==> '=' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_62048540_62025941_1237_1.java : line 15 ==> '+' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_63953744_63953084_279_0.java : line 13 ==> '-' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_64862639_60849384_88_0.java : line 7 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_67167822_67133947_1164_8.java : line 12 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_67307342_67249301_3174_4.java : line 15 ==> '+' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_6802331_6799171_931_0.java : line 87 ==> '==' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_68749390_68748641_1657_0.java : line 37 ==> ':' is not preceded with whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_6964555_6963922_3975_1.java : line 31 ==> '=' is not followed by whitespace.
# sample_ckstyl/whitespacearoundcheck/Code_81796_81723_5190_0.java : line 12 ==> '{' is not followed by whitespace.
