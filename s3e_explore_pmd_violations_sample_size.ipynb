# %%
import time
from datetime import timedelta

import html
import re

import os
import ntpath

import subprocess as sp

import numpy as np
import pandas as pd
import xml.etree.ElementTree as et

import dask
import dask.dataframe as dd
import dask.bag as bd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# %%
# Enter Path to Code Violations CSV File
code_violation_path = 'pmdcodesnippetsviolations_csv/PMDJavaCodeSnippetsViolations*.csv'
#code_violation_path = 'pmdcodesnippetsviolation_csv/pmdCodeSnippetsViolation*.csv'

# Enter Path to Real Java Code Files before performing the PMD code analisis
java_code_snippets_b4_pmd_ana = 'codesnippets_java'

# %% [markdown]
# ## Read csv files Java Answers

# %%
df = dd.read_csv(code_violation_path, engine='python', error_bad_lines=False, warn_bad_lines=False, dtype=object)

# %% [markdown]
# ## Start a Dask cluster using SLURM jobs as workers

# %%
#http://jobqueue.dask.org/en/latest/generated/dask_jobqueue.SLURMCluster.html
dask.config.set(
    {
        "distributed.worker.memory.target": False,  # avoid spilling to disk
        "distributed.worker.memory.spill": False,  # avoid spilling to disk
    }
)
cluster = SLURMCluster(
    cores=10, #cores=24, # we set each job to have 1 Worker, each using 10 cores (threads) and 8 GB of memory
    processes=2,
    memory="8GiB",
    walltime="0-00:30",# walltime="0-00:50",
    log_directory="../dask/logs",  # folder for SLURM logs for each worker
    local_directory="../dask",  # folder for workers data
)

# %% [markdown]
# Spawn between 20 to 100 workers and connect a client to be able use them.

# %%
#cluster.scale(n=20) # ask for 20 jobs or workers
# This also works with adaptive clusters. This automatically launches and kill workers based on load.
# we tell our cluster to autoscale between 10 and 20 workers depending on the load
cluster.adapt(minimum_jobs=10, maximum_jobs=200)
#cluster.adapt(maximum_jobs=20)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://192.168.94.140:44847' processes=0 threads=0, memory=0 B>

# %%
df
# Out:
# Dask DataFrame Structure:
#                 beginline endline begincolumn endcolumn    rule ruleset   class externalInfoUrl priority    text
# npartitions=204
#                    object  object      object    object  object  object  object          object   object  object
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# ...                   ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# Dask Name: read-csv, 204 tasks

# %%
pmd_codeviolations_init_len = df.shape[0].compute()
print('Initial number of volations {}'.format(pmd_codeviolations_init_len))
# Out:
# Initial number of volations 4896537

# %%
# drop empty columns
df = df[~df['class'].isna()] # Drop rows that have NaN in the Code column

# %%
pmd_codeviolations_nonan_len =df.shape[0].compute()
print('Number of violations after removing the nans in the class column {}'.format(pmd_codeviolations_nonan_len))
# Out:
# Number of violations after removing the nans in the class column 4887262

# %%
print('Difference {}'.format(pmd_codeviolations_init_len - pmd_codeviolations_nonan_len))
# Out:
# Difference 9275

# %%
# drop classes that do not have this pattern e.g., Code_10000096_9914015_1959_0
#df = df[df['class'].str.contains('^Code_\d+_\d+_\d+_\d+', regex=True)]
df = df[df['class'].str.contains('^Code_\d+_\d+_\d+_\d+$', regex=True)]

# %%
pmd_codeviolations_unkownclass_len = df.shape[0].compute()
print('Number of violations after removing the onces caused by unknown class e.g. inner classes {}'.format(pmd_codeviolations_nonan_len))
# Out:
# Number of violations after removing the onces caused by unknown class e.g. inner classes 4887262

# %%
print('Difference {}'.format(pmd_codeviolations_nonan_len - pmd_codeviolations_unkownclass_len))
# Out:
# Difference 499061

# %% [markdown]
# #### Count the unique rulesets

# %%
#count the unique rulesets
#df.groupby('ruleset').count().shape[0].compute()
#df.groupby('rule').count().shape[0].compute()

# %% [markdown]
# #### Get the unique classes dataframe

# %%
# get the unique classes
# not the values in the 1st column are where it found the 1st occurances of each unique item
#df['ruleset'].drop_duplicates().compute()

# %%
#rule_df = df[['ruleset']]
rule_df = df[['rule']]
#ruleset_df.head()

# %%
# This also counts the rows
rule_df.index.shape[0].compute()
# Out:
# 4388201

# %%
#  This also counts the unique rows
#df.groupby('ruleset').count().shape[0].compute()
df.groupby('rule').count().shape[0].compute()
# Out:
# 219

# %% [markdown]
# ### Count the number of times each item occured

# %%
#https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
rule_count_df = pd.DataFrame(rule_df.groupby('rule')['rule'].count().compute())
# rename the column to total
rule_count_df.columns=['total']
# drop the index level
rule_count_df = rule_count_df.reset_index()
rule_count_df
# Out:
#                                    rule  total
# 0    AbstractClassWithoutAbstractMethod   1704
# 1         AbstractClassWithoutAnyMethod    744
# 2                        AddEmptyString   5681
# 3               AppendCharacterWithChar   3710
# 4                 ArrayIsStoredDirectly   1745
# ..                                  ...    ...
# 214      FinalizeOnlyCallsSuperFinalize      7
# 215                     CheckSkipResult      6
# 216           LocalHomeNamingConvention      1
# 217   StringBufferInstantiationWithChar      4
# 218   MDBAndSessionBeanNamingConvention      1
#
# [219 rows x 2 columns]

# %% [raw]
# #https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
# rule_count_df = pd.DataFrame(rule_df.groupby('ruleset')['ruleset'].count().compute())
# # rename the column to total
# rule_count_df.columns=['total']
# # drop the index level
# rule_count_df = rule_count_df.reset_index()
# rule_count_df

# %% [markdown]
# ### Calculate Percentage

# %%
rule_count_df['percent'] = (rule_count_df['total']/ rule_count_df['total'].sum())*100

# %%
rule_count_df
# Out:
#                                    rule  total   percent
# 0    AbstractClassWithoutAbstractMethod   1704  0.038831
# 1         AbstractClassWithoutAnyMethod    744  0.016955
# 2                        AddEmptyString   5681  0.129461
# 3               AppendCharacterWithChar   3710  0.084545
# 4                 ArrayIsStoredDirectly   1745  0.039766
# ..                                  ...    ...       ...
# 214      FinalizeOnlyCallsSuperFinalize      7  0.000160
# 215                     CheckSkipResult      6  0.000137
# 216           LocalHomeNamingConvention      1  0.000023
# 217   StringBufferInstantiationWithChar      4  0.000091
# 218   MDBAndSessionBeanNamingConvention      1  0.000023
#
# [219 rows x 3 columns]

# %% [markdown]
# ### Calculate number to be sampled per ruleset

# %%
# https://www.surveysystem.com/sscalc.htm
# put 4887262 into the sample size calculator at 5% confidence interval
#ruleset_count_df['perc384'] = round((ruleset_count_df['percent']/ 100)*384, 0)
#ruleset_count_df

# %%
#### Better computation
import math

def comp_smpl_no(x):
    x = round((x/100)*384)
    if x < 1:
        x = 1
    return x
rule_count_df['sample_size_384'] = rule_count_df['percent'].apply(comp_smpl_no)
rule_count_df
# Out:
#                                    rule  total   percent  sample_size_384
# 0    AbstractClassWithoutAbstractMethod   1704  0.038831                1
# 1         AbstractClassWithoutAnyMethod    744  0.016955                1
# 2                        AddEmptyString   5681  0.129461                1
# 3               AppendCharacterWithChar   3710  0.084545                1
# 4                 ArrayIsStoredDirectly   1745  0.039766                1
# ..                                  ...    ...       ...              ...
# 214      FinalizeOnlyCallsSuperFinalize      7  0.000160                1
# 215                     CheckSkipResult      6  0.000137                1
# 216           LocalHomeNamingConvention      1  0.000023                1
# 217   StringBufferInstantiationWithChar      4  0.000091                1
# 218   MDBAndSessionBeanNamingConvention      1  0.000023                1
#
# [219 rows x 4 columns]

# %% [markdown]
# ### Final Sample Used

# %%
rule_count_df['sample_size_384'].sum()
# Out:
# 545

# %% [markdown]
# ### Group by Ruleset

# %%
grp_df = df.groupby('rule')

# %%
grp_df.first().head()
# Out:
#                                    beginline endline begincolumn endcolumn  \
# rule
# AbstractClassWithoutAbstractMethod         3      19          17         1
# AbstractClassWithoutAnyMethod              1       5          17         1
# AddEmptyString                            71      71          13        14
# AppendCharacterWithChar                    9       9          23        25
# ArrayIsStoredDirectly                      8       8          30        47
#
#                                            ruleset  \
# rule
# AbstractClassWithoutAbstractMethod  Best Practices
# AbstractClassWithoutAnyMethod               Design
# AddEmptyString                         Performance
# AppendCharacterWithChar                Performance
# ArrayIsStoredDirectly               Best Practices
#
#                                                             class  \
# rule
# AbstractClassWithoutAbstractMethod  Code_10119187_10117546_2825_0
# AbstractClassWithoutAnyMethod        Code_10242838_10242755_218_0
# AddEmptyString                       Code_10019347_9982894_2634_0
# AppendCharacterWithChar             Code_10049223_10049147_1819_1
# ArrayIsStoredDirectly               Code_10009891_10008708_1498_0
#
#                                                                       externalInfoUrl  \
# rule
# AbstractClassWithoutAbstractMethod  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...
# AbstractClassWithoutAnyMethod       https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...
# AddEmptyString                      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...
# AppendCharacterWithChar             https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...
# ArrayIsStoredDirectly               https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...
#
#                                    priority  \
# rule
# AbstractClassWithoutAbstractMethod        3
# AbstractClassWithoutAnyMethod             1
# AddEmptyString                            3
# AppendCharacterWithChar                   3
# ArrayIsStoredDirectly                     3
#
#                                                                                  text
# rule
# AbstractClassWithoutAbstractMethod  This abstract class does not have any abstract...
# AbstractClassWithoutAnyMethod       No abstract method which means that the keywor...
# AddEmptyString                                               Do not add empty strings
# AppendCharacterWithChar             Avoid appending characters as strings in Strin...
# ArrayIsStoredDirectly               The user-supplied array 'itemnames' is stored ...

# %%
grp_dfs = []

# %%
for vio, sample_size in zip(rule_count_df['rule'], rule_count_df['sample_size_384']): # e.g., Best Practices, Coding Style, Design
    
    subfolder = vio.lower()
    
    # Get all the values belonging to, say Best Practices
    vio_grp = grp_df.get_group(vio)
    vio_grp = vio_grp.reset_index(drop=True).compute()
    #vio_grp.head()
    
    # Randomly select that number
    #https://datatofish.com/random-rows-pandas-dataframe/
    vio_grp_ran = vio_grp.sample(n=sample_size, random_state=10)
    vio_grp_ran['sample_subfolder'] = subfolder
    # append the data frame to a list
    grp_dfs.append(vio_grp_ran)
    
    ## Make a folder in that directory
    folder = 'sample_pmd'
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    ## Make a folder in that directory
    folder = 'sample_pmd/{}'.format(subfolder)
    # output: path/to/Post.csv => path/to
    mkdir_cmd = 'mkdir {}'.format(folder)
    cmd = sp.run(
        mkdir_cmd, # command
        capture_output=True,
        text=True,
        shell=True
    )
    
    # copy list of sample java files into the destination 
    for filename_to_copy in vio_grp_ran['class']:
        file_to_copy = '{}.java'.format(filename_to_copy)
        #copy_file_cmd = 'cp codesnippets_java/{} {}'.format(file_to_copy, folder)#
        copy_file_cmd = 'cp {}/{} {}'.format(java_code_snippets_b4_pmd_ana, file_to_copy, folder)#
        
        cmd = sp.run(
            copy_file_cmd, # command
            capture_output=True,
            text=True,
            shell=True
        )

# %% [markdown]
# ### Observed Test

# %%
# Combine all the group dataframe
com_grp_dfs = pd.concat(grp_dfs)
com_grp_dfs.head()
# Out:
#    beginline endline begincolumn endcolumn  \
# 1          1      24          17         1
# 1          1       3          13         4
# 19        33      33          45        46
# 5          7       7          25        27
# 7          4       4          29        47
#
#                                   rule         ruleset  \
# 1   AbstractClassWithoutAbstractMethod  Best Practices
# 1        AbstractClassWithoutAnyMethod          Design
# 19                      AddEmptyString     Performance
# 5              AppendCharacterWithChar     Performance
# 7                ArrayIsStoredDirectly  Best Practices
#
#                             class  \
# 1    Code_19285266_19280680_341_1
# 1   Code_11109133_11108982_3813_0
# 19  Code_59116818_59116662_2175_0
# 5     Code_9467897_9467854_2670_0
# 7   Code_22177928_22177569_1464_0
#
#                                       externalInfoUrl priority  \
# 1   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 1   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# 19  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 5   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 7   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                  text  \
# 1   This abstract class does not have any abstract...
# 1   No abstract method which means that the keywor...
# 19                           Do not add empty strings
# 5   Avoid appending characters as strings in Strin...
# 7   The user-supplied array 'commands' is stored d...
#
#                       sample_subfolder
# 1   abstractclasswithoutabstractmethod
# 1        abstractclasswithoutanymethod
# 19                      addemptystring
# 5              appendcharacterwithchar
# 7                arrayisstoreddirectly

# %% [markdown]
# ### Sort them in order

# %%
com_grp_dfs.sort_values('class', ascending=True, inplace=True)
#com_grp_dfs.sort_values('class', ascending=True, inplace=True)
com_grp_dfs.sort_values(['sample_subfolder','class'], ascending=[True, True], inplace=True)

# %%
com_grp_dfs.head()
# Out:
#    beginline endline begincolumn endcolumn  \
# 1          1      24          17         1
# 1          1       3          13         4
# 19        33      33          45        46
# 5          7       7          25        27
# 7          4       4          29        47
#
#                                   rule         ruleset  \
# 1   AbstractClassWithoutAbstractMethod  Best Practices
# 1        AbstractClassWithoutAnyMethod          Design
# 19                      AddEmptyString     Performance
# 5              AppendCharacterWithChar     Performance
# 7                ArrayIsStoredDirectly  Best Practices
#
#                             class  \
# 1    Code_19285266_19280680_341_1
# 1   Code_11109133_11108982_3813_0
# 19  Code_59116818_59116662_2175_0
# 5     Code_9467897_9467854_2670_0
# 7   Code_22177928_22177569_1464_0
#
#                                       externalInfoUrl priority  \
# 1   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 1   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# 19  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 5   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 7   https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                  text  \
# 1   This abstract class does not have any abstract...
# 1   No abstract method which means that the keywor...
# 19                           Do not add empty strings
# 5   Avoid appending characters as strings in Strin...
# 7   The user-supplied array 'commands' is stored d...
#
#                       sample_subfolder
# 1   abstractclasswithoutabstractmethod
# 1        abstractclasswithoutanymethod
# 19                      addemptystring
# 5              appendcharacterwithchar
# 7                arrayisstoreddirectly

# %%
for rls, subfol, cls, bln, eln, msg in zip(com_grp_dfs['ruleset'], com_grp_dfs['sample_subfolder'], com_grp_dfs['class'], com_grp_dfs['beginline'], com_grp_dfs['endline'], com_grp_dfs['text']):
    print('sample_pmd/{}/{}.java : lines {} to {} ==> {} ({})'.format(subfol, cls, bln, eln, msg, rls))
# Out:
# sample_pmd/abstractclasswithoutabstractmethod/Code_19285266_19280680_341_1.java : lines 1 to 24 ==> This abstract class does not have any abstract methods (Best Practices)
# sample_pmd/abstractclasswithoutanymethod/Code_11109133_11108982_3813_0.java : lines 1 to 3 ==> No abstract method which means that the keyword is most likely used to prevent instantiation. Use a private or protected constructor instead. (Design)
# sample_pmd/addemptystring/Code_59116818_59116662_2175_0.java : lines 33 to 33 ==> Do not add empty strings (Performance)
# sample_pmd/appendcharacterwithchar/Code_9467897_9467854_2670_0.java : lines 7 to 7 ==> Avoid appending characters as strings in StringBuffer.append. (Performance)
# sample_pmd/arrayisstoreddirectly/Code_22177928_22177569_1464_0.java : lines 4 to 4 ==> The user-supplied array 'commands' is stored directly. (Best Practices)
# sample_pmd/assignmenttononfinalstatic/Code_51099286_51097885_2851_2.java : lines 6 to 6 ==> Possible unsafe assignment to a non-final static field in a constructor. (Error Prone)
# sample_pmd/avoidarrayloops/Code_22369268_12517764_5715_0.java : lines 8 to 10 ==> System.arraycopy is more efficient (Performance)
# sample_pmd/avoidbranchingstatementaslastinloop/Code_3601523_3601472_673_0.java : lines 16 to 16 ==> Avoid using a branching statement as the last in a loop. (Error Prone)
# sample_pmd/avoidcalendardatecreation/Code_12549855_12549634_1477_6.java : lines 16 to 16 ==> A Calendar is used to create a Date or DateTime, this is expensive. (Performance)
# sample_pmd/avoidcallingfinalize/Code_46009669_24016962_8_20.java : lines 4 to 4 ==> Avoid calling finalize() explicitly (Error Prone)
# sample_pmd/avoidcatchinggenericexception/Code_2085658_2085584_190_8.java : lines 10 to 10 ==> Avoid catching generic exceptions such as NullPointerException, RuntimeException, Exception in try-catch block (Design)
# sample_pmd/avoidcatchinggenericexception/Code_51505230_51505023_782_7.java : lines 7 to 7 ==> Avoid catching generic exceptions such as NullPointerException, RuntimeException, Exception in try-catch block (Design)
# sample_pmd/avoidcatchingnpe/Code_35289982_32711975_2029_1.java : lines 45 to 45 ==> Avoid catching NullPointerException; consider removing the cause of the NPE. (Error Prone)
# sample_pmd/avoidcatchingthrowable/Code_1840104_1839671_2222_3.java : lines 20 to 22 ==> A catch statement should never catch throwable since it includes errors. (Error Prone)
# sample_pmd/avoiddecimalliteralsinbigdecimalconstructor/Code_8754703_8754410_1562_0.java : lines 6 to 6 ==> Avoid creating BigDecimal with a decimal (float/double) literal. Use a String literal (Error Prone)
# sample_pmd/avoiddeeplynestedifstmts/Code_28700366_28617682_3068_0.java : lines 16 to 24 ==> Deeply nested if..then statements are hard to read (Design)
# sample_pmd/avoiddollarsigns/Code_49651888_49078219_244_0.java : lines 15 to 15 ==> Avoid using dollar signs in variable/method/class/interface names (Code Style)
# sample_pmd/avoidduplicateliterals/Code_19315051_19313765_326_4.java : lines 26 to 26 ==> The String literal ".\n" appears 4 times in this file; the first occurrence is on line 26 (Error Prone)
# sample_pmd/avoidfieldnamematchingmethodname/Code_16646865_16641037_822_1.java : lines 2 to 2 ==> Field toggle has the same name as a method (Error Prone)
# sample_pmd/avoidfilestream/Code_13447565_13447522_1127_1.java : lines 24 to 24 ==> Avoid instantiating FileInputStream, FileOutputStream, FileReader, or FileWriter (Performance)
# sample_pmd/avoidinstanceofchecksincatchclause/Code_62027895_39285329_946_0.java : lines 65 to 65 ==> An instanceof check is being performed on the caught exception.  Create a separate catch clause for this exception type. (Error Prone)
# sample_pmd/avoidinstantiatingobjectsinloops/Code_10477658_10474963_3269_1.java : lines 11 to 11 ==> Avoid instantiating new objects inside loops (Performance)
# sample_pmd/avoidinstantiatingobjectsinloops/Code_51848223_51847401_2535_0.java : lines 24 to 24 ==> Avoid instantiating new objects inside loops (Performance)
# sample_pmd/avoidlosingexceptioninformation/Code_19163962_19161977_4801_1.java : lines 8 to 8 ==> Avoid statements in a catch block that invoke accessors on the exception without using the information (Error Prone)
# sample_pmd/avoidmessagedigestfield/Code_9458904_9365279_2543_0.java : lines 7 to 7 ==> You shouldnt declare field of MessageDigest type, because unsynchronized access could cause problems (Best Practices)
# sample_pmd/avoidmultipleunaryoperators/Code_49247686_36160674_128_0.java : lines 6 to 6 ==> Using multiple unary operators may be a bug, and/or is confusing. (Error Prone)
# sample_pmd/avoidprintstacktrace/Code_23356324_23356177_2412_2.java : lines 16 to 16 ==> Avoid printStackTrace(); use a logger call instead. (Best Practices)
# sample_pmd/avoidprintstacktrace/Code_53477681_53474375_179_1.java : lines 7 to 7 ==> Avoid printStackTrace(); use a logger call instead. (Best Practices)
# sample_pmd/avoidprintstacktrace/Code_8305989_8305501_2318_0.java : lines 63 to 63 ==> Avoid printStackTrace(); use a logger call instead. (Best Practices)
# sample_pmd/avoidprotectedfieldinfinalclass/Code_50678941_50678480_411_0.java : lines 38 to 38 ==> Avoid protected fields in a final class.  Change to private or package access. (Code Style)
# sample_pmd/avoidprotectedmethodinfinalclassnotextending/Code_61968561_61923351_639_6.java : lines 57 to 74 ==> Avoid protected methods in a final class that doesnt extend anything other than Object.  Change to private or package access. (Code Style)
# sample_pmd/avoidreassigningcatchvariables/Code_45550354_45547829_851_1.java : lines 10 to 10 ==> Avoid reassigning caught exception 'e' (Best Practices)
# sample_pmd/avoidreassigningloopvariables/Code_28509368_28508641_4577_0.java : lines 48 to 48 ==> Avoid reassigning the loop control variable 'i' (Best Practices)
# sample_pmd/avoidreassigningparameters/Code_66650643_66649878_11_1.java : lines 6 to 6 ==> Avoid reassigning parameters such as 'string1' (Best Practices)
# sample_pmd/avoidrethrowingexception/Code_6053311_6049119_441_0.java : lines 73 to 76 ==> A catch statement that catches an exception only to rethrow it should be avoided. (Design)
# sample_pmd/avoidstringbufferfield/Code_58541231_37900719_1116_0.java : lines 2 to 2 ==> StringBuffers can grow quite a lot, and so may become a source of memory leak (if the owning class has a long life time). (Best Practices)
# sample_pmd/avoidsynchronizedatmethodlevel/Code_37241772_37240331_483_3.java : lines 2 to 12 ==> Use block level rather than method level synchronization (Multithreading)
# sample_pmd/avoidthreadgroup/Code_54022338_7939257_747_4.java : lines 19 to 19 ==> Avoid using java.lang.ThreadGroup; it is not thread safe (Multithreading)
# sample_pmd/avoidthrowingnewinstanceofsameexception/Code_5440285_2225344_2074_0.java : lines 108 to 111 ==> A catch statement that catches an exception only to wrap it in a new instance of the same type of exception and throw it should be avoided (Design)
# sample_pmd/avoidthrowingnullpointerexception/Code_19768584_19768540_2608_10.java : lines 3 to 3 ==> Avoid throwing null pointer exceptions. (Design)
# sample_pmd/avoidthrowingrawexceptiontypes/Code_45094872_45088971_1907_14.java : lines 34 to 34 ==> Avoid throwing raw exception types. (Design)
# sample_pmd/avoiduncheckedexceptionsinsignatures/Code_26108654_26098817_950_1.java : lines 18 to 18 ==> A method or constructor should not explicitly declare unchecked exceptions in its 'throws' clause (Design)
# sample_pmd/avoidusinghardcodedip/Code_44436295_44436098_4238_0.java : lines 31 to 31 ==> Do not hard code the IP address  (Best Practices)
# sample_pmd/avoidusingoctalvalues/Code_2848058_2847728_74_3.java : lines 2 to 2 ==> Do not start a literal by 0 unless its an octal value (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_10875150_10874996_311_0.java : lines 94 to 94 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_13060588_13042015_2128_0.java : lines 2 to 2 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_187056_138157_2562_0.java : lines 25 to 25 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_19509165_19508958_5965_2.java : lines 2 to 2 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_22612667_22612364_4528_0.java : lines 2 to 2 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_23103294_23103028_1269_8.java : lines 6 to 6 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_24670671_24555689_77_0.java : lines 3 to 3 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_27588612_27588490_2576_2.java : lines 10 to 10 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_31314577_31313633_1093_0.java : lines 4 to 4 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_34401627_34086303_268_1.java : lines 12 to 12 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_3625194_3624852_1252_0.java : lines 3 to 3 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_4174856_4174379_1553_0.java : lines 4 to 4 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_43308558_43303068_2578_1.java : lines 38 to 38 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_47185553_17315842_517_1.java : lines 4 to 4 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_49933455_49933024_163_2.java : lines 30 to 30 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_54970761_54969680_3806_3.java : lines 18 to 18 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_57271116_57270676_807_4.java : lines 4 to 4 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_63981276_63980194_186_0.java : lines 16 to 16 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/beanmembersshouldserialize/Code_9827690_9827517_1333_0.java : lines 15 to 15 ==> Found non-transient, non-static member. Please mark as transient or provide accessors. (Error Prone)
# sample_pmd/bigintegerinstantiation/Code_49098290_49094372_3738_0.java : lines 68 to 68 ==> Dont create instances of already existing BigInteger and BigDecimal (ZERO, ONE, TEN) (Performance)
# sample_pmd/booleangetmethodname/Code_16721267_16718572_1167_5.java : lines 2 to 4 ==> A getX() method which returns a boolean should be named isX() (Code Style)
# sample_pmd/brokennullcheck/Code_16384133_16383578_371_0.java : lines 37 to 41 ==> Method call on object which may be null (Error Prone)
# sample_pmd/callsuperfirst/Code_16280066_16169488_3444_6.java : lines 13 to 15 ==> super should be called at the start of the method (Error Prone)
# sample_pmd/callsuperinconstructor/Code_20344741_20344601_1583_0.java : lines 18 to 43 ==> It is a good practice to call super() in a constructor (Code Style)
# sample_pmd/callsuperlast/Code_28844773_28844369_506_0.java : lines 20 to 20 ==> super should be called at the end of the method (Error Prone)
# sample_pmd/checkresultset/Code_32106565_32077930_1155_0.java : lines 33 to 33 ==> Always check the return of one of the navigation method (next,previous,first,last) of a ResultSet. (Best Practices)
# sample_pmd/checkskipresult/Code_9845277_5223340_722_2.java : lines 131 to 131 ==> Check the value returned by the skip() method of an InputStream to see if the requested number of bytes has been skipped. (Error Prone)
# sample_pmd/classcastexceptionwithtoarray/Code_38262680_21624592_1482_0.java : lines 3 to 3 ==> This usage of the Collection.toArray() method will throw a ClassCastException. (Error Prone)
# sample_pmd/classnamingconventions/Code_11377771_11377480_2591_0.java : lines 1 to 4 ==> The class name 'Code_11377771_11377480_2591_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_13564478_13551408_4087_2.java : lines 1 to 14 ==> The class name 'Code_13564478_13551408_4087_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_13934089_13933997_307_2.java : lines 1 to 4 ==> The class name 'Code_13934089_13933997_307_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_14533718_14533642_548_0.java : lines 1 to 4 ==> The class name 'Code_14533718_14533642_548_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_15147808_15147780_1345_1.java : lines 1 to 6 ==> The class name 'Code_15147808_15147780_1345_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_17469063_17469021_1744_0.java : lines 1 to 4 ==> The class name 'Code_17469063_17469021_1744_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_17812896_17812322_2030_6.java : lines 1 to 4 ==> The class name 'Code_17812896_17812322_2030_6' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_18116462_18108315_896_12.java : lines 1 to 6 ==> The class name 'Code_18116462_18108315_896_12' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_18773039_18772913_1706_2.java : lines 1 to 7 ==> The class name 'Code_18773039_18772913_1706_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_19469797_19468752_5035_0.java : lines 15 to 80 ==> The class name 'Code_19469797_19468752_5035_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_20187759_20187589_596_0.java : lines 1 to 1 ==> The class name 'Code_20187759_20187589_596_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_20251501_20251227_1063_2.java : lines 1 to 6 ==> The interface name 'Code_20251501_20251227_1063_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_21138857_21138451_1194_1.java : lines 1 to 12 ==> The class name 'Code_21138857_21138451_1194_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_22160560_22160528_596_3.java : lines 1 to 4 ==> The class name 'Code_22160560_22160528_596_3' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_23119944_23119830_3473_0.java : lines 1 to 33 ==> The class name 'Code_23119944_23119830_3473_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_23951206_23951148_1453_0.java : lines 1 to 5 ==> The class name 'Code_23951206_23951148_1453_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_24914704_24914555_4866_1.java : lines 1 to 24 ==> The class name 'Code_24914704_24914555_4866_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_27101953_21008033_4417_1.java : lines 1 to 15 ==> The class name 'Code_27101953_21008033_4417_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_27121011_27120914_671_0.java : lines 1 to 4 ==> The utility class name 'Code_27121011_27120914_671_0' doesn't match '[A-Z][a-zA-Z0-9]+(Utils?|Helper|Constants)' (Code Style)
# sample_pmd/classnamingconventions/Code_28971109_8166187_2323_2.java : lines 1 to 6 ==> The class name 'Code_28971109_8166187_2323_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_29453658_29395340_1973_1.java : lines 1 to 15 ==> The class name 'Code_29453658_29395340_1973_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_29636504_29636311_14_1.java : lines 1 to 4 ==> The class name 'Code_29636504_29636311_14_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_30492773_30492166_1305_0.java : lines 1 to 26 ==> The class name 'Code_30492773_30492166_1305_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_31230506_31230475_54_0.java : lines 1 to 5 ==> The class name 'Code_31230506_31230475_54_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_32502140_32502003_4275_3.java : lines 1 to 28 ==> The class name 'Code_32502140_32502003_4275_3' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_32546458_32546176_316_1.java : lines 1 to 5 ==> The class name 'Code_32546458_32546176_316_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_3335789_2618833_1762_0.java : lines 1 to 15 ==> The class name 'Code_3335789_2618833_1762_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_33612209_33611188_755_1.java : lines 1 to 38 ==> The class name 'Code_33612209_33611188_755_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_33911289_33910997_505_0.java : lines 1 to 4 ==> The class name 'Code_33911289_33910997_505_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_34888387_34888219_373_1.java : lines 1 to 9 ==> The class name 'Code_34888387_34888219_373_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_38107441_38106111_1356_11.java : lines 1 to 20 ==> The utility class name 'Code_38107441_38106111_1356_11' doesn't match '[A-Z][a-zA-Z0-9]+(Utils?|Helper|Constants)' (Code Style)
# sample_pmd/classnamingconventions/Code_38381224_38380851_267_1.java : lines 1 to 22 ==> The class name 'Code_38381224_38380851_267_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_39943692_39943581_2206_0.java : lines 1 to 9 ==> The class name 'Code_39943692_39943581_2206_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_40810546_40810324_3685_2.java : lines 1 to 32 ==> The class name 'Code_40810546_40810324_3685_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_40922724_40922519_30_0.java : lines 1 to 12 ==> The class name 'Code_40922724_40922519_30_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_41800667_41800495_1833_0.java : lines 1 to 10 ==> The class name 'Code_41800667_41800495_1833_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_42951880_42951649_662_1.java : lines 1 to 27 ==> The class name 'Code_42951880_42951649_662_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_43698504_43698412_179_0.java : lines 1 to 5 ==> The class name 'Code_43698504_43698412_179_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_44228489_43297897_120_0.java : lines 1 to 9 ==> The utility class name 'Code_44228489_43297897_120_0' doesn't match '[A-Z][a-zA-Z0-9]+(Utils?|Helper|Constants)' (Code Style)
# sample_pmd/classnamingconventions/Code_46137908_46137793_1970_3.java : lines 1 to 4 ==> The class name 'Code_46137908_46137793_1970_3' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_46333195_46333012_1081_1.java : lines 1 to 4 ==> The class name 'Code_46333195_46333012_1081_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_4725052_4193373_3283_2.java : lines 1 to 17 ==> The utility class name 'Code_4725052_4193373_3283_2' doesn't match '[A-Z][a-zA-Z0-9]+(Utils?|Helper|Constants)' (Code Style)
# sample_pmd/classnamingconventions/Code_48663517_48663467_569_0.java : lines 1 to 4 ==> The class name 'Code_48663517_48663467_569_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_48874352_48868110_198_2.java : lines 11 to 82 ==> The class name 'Code_48874352_48868110_198_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_48899654_37623430_181_0.java : lines 2 to 8 ==> The class name 'Code_48899654_37623430_181_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_50124768_50124419_3953_2.java : lines 1 to 6 ==> The class name 'Code_50124768_50124419_3953_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_5188182_5076740_304_0.java : lines 1 to 5 ==> The class name 'Code_5188182_5076740_304_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_52186314_51992722_27_1.java : lines 1 to 6 ==> The class name 'Code_52186314_51992722_27_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_52518250_52518150_586_1.java : lines 1 to 32 ==> The class name 'Code_52518250_52518150_586_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_53687636_53685206_3686_0.java : lines 1 to 20 ==> The class name 'Code_53687636_53685206_3686_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_54049995_54049904_1158_0.java : lines 1 to 6 ==> The class name 'Code_54049995_54049904_1158_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_54740916_7317243_223_0.java : lines 1 to 36 ==> The class name 'Code_54740916_7317243_223_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_58532448_58532147_952_0.java : lines 1 to 18 ==> The class name 'Code_58532448_58532147_952_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_60750976_28951336_702_0.java : lines 1 to 25 ==> The class name 'Code_60750976_28951336_702_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_62564251_62564191_1611_2.java : lines 1 to 9 ==> The class name 'Code_62564251_62564191_1611_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_6391616_6391539_3424_0.java : lines 1 to 4 ==> The class name 'Code_6391616_6391539_3424_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_65159476_65159400_1131_0.java : lines 1 to 8 ==> The utility class name 'Code_65159476_65159400_1131_0' doesn't match '[A-Z][a-zA-Z0-9]+(Utils?|Helper|Constants)' (Code Style)
# sample_pmd/classnamingconventions/Code_68582898_68582548_141_0.java : lines 1 to 35 ==> The class name 'Code_68582898_68582548_141_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_6889648_6889580_2934_0.java : lines 1 to 16 ==> The class name 'Code_6889648_6889580_2934_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_7787971_7785887_641_1.java : lines 1 to 11 ==> The class name 'Code_7787971_7785887_641_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_8215329_8215282_3673_0.java : lines 1 to 6 ==> The class name 'Code_8215329_8215282_3673_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_8693629_8693237_675_1.java : lines 1 to 62 ==> The class name 'Code_8693629_8693237_675_1' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_9157182_9157132_2467_0.java : lines 2 to 12 ==> The class name 'Code_9157182_9157132_2467_0' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classnamingconventions/Code_9395773_9395490_1644_2.java : lines 1 to 18 ==> The class name 'Code_9395773_9395490_1644_2' doesn't match '[A-Z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/classwithonlyprivateconstructorsshouldbefinal/Code_6510855_6510790_2510_0.java : lines 1 to 11 ==> A class which only has private constructors should be final (Design)
# sample_pmd/clonemethodmustbepublic/Code_12213395_12213369_1003_4.java : lines 4 to 10 ==> clone() method must be public if the class implements Cloneable (Error Prone)
# sample_pmd/clonemethodmustimplementcloneable/Code_41007070_41006429_2657_3.java : lines 25 to 30 ==> clone() method should be implemented only if implementing Cloneable interface (Error Prone)
# sample_pmd/clonemethodreturntypemustmatchclassname/Code_37320886_37320734_1787_0.java : lines 7 to 9 ==> The return type of the clone() method must be the class name when implements Cloneable (Error Prone)
# sample_pmd/closeresource/Code_31278356_31278244_670_0.java : lines 19 to 19 ==> Ensure that resources like this Scanner object are closed after use (Error Prone)
# sample_pmd/closeresource/Code_57470519_57469863_22_2.java : lines 9 to 9 ==> Ensure that resources like this InputStream object are closed after use (Error Prone)
# sample_pmd/cognitivecomplexity/Code_29903164_1934399_148_0.java : lines 2 to 46 ==> The method 'parser(char)' has a cognitive complexity of 17, current threshold is 15 (Design)
# sample_pmd/collapsibleifstatements/Code_12740581_12740445_742_0.java : lines 11 to 12 ==> These nested if statements could be combined (Design)
# sample_pmd/compareobjectswithequals/Code_31542942_16729045_1026_0.java : lines 5 to 5 ==> Use equals() to compare object references. (Error Prone)
# sample_pmd/comparisonwithnan/Code_68100313_30443727_1783_0.java : lines 27 to 27 ==> Comparisons with NaN always return false (Error Prone)
# sample_pmd/confusingternary/Code_67354481_67354109_851_0.java : lines 22 to 31 ==> Avoid if (x != y) ..; else ..; (Code Style)
# sample_pmd/consecutiveappendsshouldreuse/Code_7663966_625433_465_0.java : lines 26 to 26 ==> StringBuffer (or StringBuilder).append is called consecutively without reusing the target variable. (Performance)
# sample_pmd/consecutiveliteralappends/Code_49936139_49935385_743_0.java : lines 6 to 6 ==> StringBuffer (or StringBuilder).append is called 2 consecutive times with literals. Use a single append with a single combined String. (Performance)
# sample_pmd/constantsininterface/Code_11625335_11624752_2029_0.java : lines 2 to 2 ==> Avoid constants in interfaces. Interfaces define types, constants are implementation details better placed in classes or enums. See Effective Java, item 19. (Best Practices)
# sample_pmd/constructorcallsoverridablemethod/Code_35421547_35413599_655_0.java : lines 9 to 9 ==> Overridable method 'createArrayX' called during object construction (Error Prone)
# sample_pmd/controlstatementbraces/Code_13845078_9109438_2358_0.java : lines 61 to 61 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_14978809_13109829_3013_0.java : lines 85 to 86 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_18003449_18003206_3933_0.java : lines 11 to 11 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_20853879_20853856_704_0.java : lines 9 to 9 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_22561390_22555110_2269_7.java : lines 20 to 20 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_35980881_20969211_1420_0.java : lines 14 to 14 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_42187988_42187880_82_1.java : lines 22 to 22 ==> This statement should have braces (Code Style)
# sample_pmd/controlstatementbraces/Code_66225650_66225364_82_3.java : lines 28 to 28 ==> This statement should have braces (Code Style)
# sample_pmd/couplingbetweenobjects/Code_55847984_21833537_387_0.java : lines 1 to 398 ==> High amount of different objects as members denotes a high coupling (Design)
# sample_pmd/dataclass/Code_20522073_20459375_2521_1.java : lines 8 to 34 ==> The class 'Code_20522073_20459375_2521_1' is suspected to be a Data Class (WOC=0.000%, NOPA=0, NOAM=13, WMC=14) (Design)
# sample_pmd/defaultlabelnotlastinswitchstmt/Code_20639340_20638967_121_1.java : lines 6 to 14 ==> The default label should be the last label in a switch statement (Best Practices)
# sample_pmd/donotextendjavalangerror/Code_5588543_5588474_3562_1.java : lines 1 to 1 ==> Exceptions should not extend java.lang.Error (Design)
# sample_pmd/donothardcodesdcard/Code_19112034_18750892_1322_0.java : lines 20 to 20 ==> Do not hardcode /sdcard. (Error Prone)
# sample_pmd/donotterminatevm/Code_46880986_46880899_1454_0.java : lines 10 to 10 ==> System.exit() should not be used in J2EE/JEE apps (Error Prone)
# sample_pmd/donotthrowexceptioninfinally/Code_16481342_16481313_2398_2.java : lines 9 to 20 ==> A throw statement in a finally block makes the control flow hard to understand. (Error Prone)
# sample_pmd/donotusethreads/Code_30332640_30276406_1082_5.java : lines 43 to 43 ==> To be compliant to J2EE, a webapp should not use any thread. (Multithreading)
# sample_pmd/donotusethreads/Code_51573642_51573496_1069_8.java : lines 8 to 8 ==> To be compliant to J2EE, a webapp should not use any thread. (Multithreading)
# sample_pmd/dontcallthreadrun/Code_26831404_26831190_4604_0.java : lines 44 to 44 ==> Dont call Thread.run() explicitly, use Thread.start() (Multithreading)
# sample_pmd/dontusefloattypeforloopindices/Code_32529034_32491046_4748_0.java : lines 74 to 74 ==> Dont use floating point for loop indices. If you must use floating point, use double. (Error Prone)
# sample_pmd/doublebraceinitialization/Code_12670428_12670398_197_0.java : lines 3 to 6 ==> Double-brace initialization should be avoided (Best Practices)
# sample_pmd/doublecheckedlocking/Code_32561947_32557830_615_0.java : lines 7 to 21 ==> Double checked locking is not thread safe in Java. (Multithreading)
# sample_pmd/emptycatchblock/Code_47485351_47484838_3076_0.java : lines 84 to 86 ==> Avoid empty catch blocks (Error Prone)
# sample_pmd/emptyfinalizer/Code_51992863_51992747_931_0.java : lines 2 to 2 ==> Avoid empty finalize methods (Error Prone)
# sample_pmd/emptyfinallyblock/Code_9354642_9354599_571_0.java : lines 19 to 22 ==> Avoid empty finally blocks (Error Prone)
# sample_pmd/emptyifstmt/Code_29722794_29722675_334_0.java : lines 14 to 15 ==> Avoid empty if statements (Error Prone)
# sample_pmd/emptyinitializer/Code_16131986_16130420_2564_0.java : lines 79 to 79 ==> Empty initializer was found (Error Prone)
# sample_pmd/emptymethodinabstractclassshouldbeabstract/Code_40923931_40923824_168_7.java : lines 8 to 10 ==> An empty method in an abstract class should be abstract instead (Code Style)
# sample_pmd/emptystatementblock/Code_29896863_29896767_45_0.java : lines 9 to 11 ==> Avoid empty block statements. (Error Prone)
# sample_pmd/emptystatementnotinloop/Code_34001869_34000356_2036_0.java : lines 34 to 34 ==> An empty statement (semicolon) not part of a loop (Error Prone)
# sample_pmd/emptyswitchstatements/Code_24492665_24205234_1278_0.java : lines 17 to 19 ==> Avoid empty switch statements (Error Prone)
# sample_pmd/emptysynchronizedblock/Code_45237404_45223197_12_2.java : lines 5 to 7 ==> Avoid empty synchronized blocks (Error Prone)
# sample_pmd/emptytryblock/Code_27648738_27648068_2519_0.java : lines 95 to 97 ==> Avoid empty try blocks (Error Prone)
# sample_pmd/emptywhilestmt/Code_55733830_55731837_35_1.java : lines 16 to 16 ==> Avoid empty while statements (Error Prone)
# sample_pmd/equalsnull/Code_55375585_9151619_2384_0.java : lines 28 to 28 ==> Avoid using equals() to compare against null (Error Prone)
# sample_pmd/exceptionasflowcontrol/Code_63612967_63611752_2496_1.java : lines 11 to 11 ==> Avoid using exceptions as flow control. (Design)
# sample_pmd/excessiveimports/Code_62027895_39285329_946_0.java : lines 1 to 214 ==> A high number of imports can indicate a high degree of coupling within an object. (Design)
# sample_pmd/extendsobject/Code_50705289_50704896_875_0.java : lines 1 to 1 ==> No need to explicitly extend Object. (Code Style)
# sample_pmd/fielddeclarationsshouldbeatstartofclass/Code_8277824_8277464_2328_0.java : lines 33 to 37 ==> Fields should be declared at the top of the class, before any method declarations, constructors, initializers or inner classes. (Code Style)
# sample_pmd/fieldnamingconventions/Code_19342829_19342802_438_2.java : lines 5 to 5 ==> The constant name 'barLock' doesn't match '[A-Z][A-Z_0-9]*' (Code Style)
# sample_pmd/fieldnamingconventions/Code_31739081_31697314_4707_0.java : lines 10 to 10 ==> The field name '_field' doesn't match '[a-z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/fieldnamingconventions/Code_7512456_7511466_2507_0.java : lines 4 to 4 ==> The field name 'in_subtag2' doesn't match '[a-z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/finalfieldcouldbestatic/Code_45482379_45482249_527_1.java : lines 2 to 2 ==> This final field could be made static (Design)
# sample_pmd/finalizeonlycallssuperfinalize/Code_17655499_17655366_3042_4.java : lines 19 to 19 ==> Finalize should do something besides just calling super.finalize() (Error Prone)
# sample_pmd/finalizeoverloaded/Code_29774157_29773942_1283_5.java : lines 16 to 19 ==> Finalize methods should not be overloaded (Error Prone)
# sample_pmd/finalizeshouldbeprotected/Code_2433288_2433261_63_6.java : lines 8 to 10 ==> If you override finalize(), make it protected (Error Prone)
# sample_pmd/forloopshouldbewhileloop/Code_24484915_24483199_1174_1.java : lines 45 to 49 ==> This for loop could be simplified to a while loop (Code Style)
# sample_pmd/formalparameternamingconventions/Code_42248330_42247075_1784_0.java : lines 210 to 210 ==> The method parameter name 'Url' doesn't match '[a-z][a-zA-Z0-9]*' (Code Style)
# sample_pmd/godclass/Code_16263683_6709913_4973_0.java : lines 11 to 250 ==> Possible God Class (WMC=57, ATFD=8, TCC=16.667%) (Design)
# sample_pmd/guardlogstatement/Code_20162107_20136150_797_1.java : lines 13 to 13 ==> Logger calls should be surrounded by log level guards. (Best Practices)
# sample_pmd/idempotentoperations/Code_29550500_29550082_3973_0.java : lines 4 to 4 ==> Avoid idempotent operations (like assigning a variable to itself). (Error Prone)
# sample_pmd/immutablefield/Code_10770599_8667506_677_0.java : lines 2 to 2 ==> Private field 'mRect' could be made final; it is only initialized in the declaration or constructor. (Design)
# sample_pmd/immutablefield/Code_40204152_40202689_538_3.java : lines 21 to 21 ==> Private field 'colRowTextArea' could be made final; it is only initialized in the declaration or constructor. (Design)
# sample_pmd/immutablefield/Code_52080227_52079885_298_2.java : lines 22 to 22 ==> Private field 'gifLabel' could be made final; it is only initialized in the declaration or constructor. (Design)
# sample_pmd/immutablefield/Code_57078929_57078777_928_7.java : lines 4 to 4 ==> Private field 'fuel' could be made final; it is only initialized in the declaration or constructor. (Design)
# sample_pmd/implicitswitchfallthrough/Code_46813404_46812878_185_1.java : lines 5 to 18 ==> A switch statement does not contain a break (Error Prone)
# sample_pmd/inefficientemptystringcheck/Code_11329428_11329336_2018_0.java : lines 69 to 69 ==> String.trim().length() == 0 / String.trim().isEmpty() is an inefficient way to validate a blank String. (Performance)
# sample_pmd/inefficientstringbuffering/Code_46868699_21412148_645_0.java : lines 30 to 30 ==> Avoid concatenating nonliterals in a StringBuffer/StringBuilder constructor or append(). (Performance)
# sample_pmd/insecurecryptoiv/Code_55760193_55757515_479_0.java : lines 37 to 37 ==> Do not use hard coded initialization vector in crypto operations (Security)
# sample_pmd/instantiationtogetclass/Code_9852722_9852220_2086_0.java : lines 34 to 34 ==> Avoid instantiating an object just to call getClass() on it; use the .class public member instead (Error Prone)
# sample_pmd/insufficientstringbufferdeclaration/Code_40863134_40862239_14_0.java : lines 14 to 14 ==> StringBuilder has been initialized with size 16, but has at least 36 characters appended. (Performance)
# sample_pmd/jumbledincrementer/Code_18542170_18542037_2366_3.java : lines 10 to 12 ==> Avoid modifying an outer loop incrementer in an inner loop for update expression (Error Prone)
# sample_pmd/junit4suitesshouldusesuiteannotation/Code_512707_197372_152_4.java : lines 39 to 41 ==> JUnit 4 indicates test suites via annotations, not the suite method. (Best Practices)
# sample_pmd/junit4testshoulduseafterannotation/Code_12534726_12534657_1016_1.java : lines 22 to 26 ==> JUnit 4 tests that clean up tests should use the @After annotation, JUnit5 tests should use @AfterEach or @AfterAll (Best Practices)
# sample_pmd/junit4testshouldusebeforeannotation/Code_5211644_5211194_3397_0.java : lines 6 to 10 ==> JUnit 4 tests that set up tests should use the @Before annotation, JUnit5 tests should use @BeforeEach or @BeforeAll (Best Practices)
# sample_pmd/junit4testshouldusetestannotation/Code_23828982_23649839_221_1.java : lines 44 to 51 ==> JUnit 4 tests that execute tests should use the @Test annotation, JUnit 5 tests should use @Test, @RepeatedTest, @TestFactory, @TestTemplate or @ParameterizedTest (Best Practices)
# sample_pmd/junitassertionsshouldincludemessage/Code_43669969_43629355_4362_3.java : lines 43 to 43 ==> JUnit assertions should include a message (Best Practices)
# sample_pmd/junittestcontainstoomanyasserts/Code_42177700_42177532_596_3.java : lines 3 to 10 ==> Unit tests should not contain more than 1 assert(s). (Best Practices)
# sample_pmd/junittestsshouldincludeassert/Code_58666600_58509194_3094_0.java : lines 52 to 54 ==> JUnit tests should include assert() or fail() (Best Practices)
# sample_pmd/junituseexpected/Code_49067307_29885428_1127_3.java : lines 71 to 71 ==> In JUnit4, use the @Test(expected) annotation to denote tests that should throw exceptions (Best Practices)
# sample_pmd/lawofdemeter/Code_11049638_11048579_2428_0.java : lines 49 to 49 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_12400544_12400466_226_3.java : lines 9 to 9 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_13971185_13970978_205_0.java : lines 9 to 9 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_14083796_14083628_2385_0.java : lines 6 to 6 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_16285135_16283770_5368_3.java : lines 50 to 50 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_17314297_17190323_2316_1.java : lines 262 to 262 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_17420421_7054584_1651_4.java : lines 13 to 13 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_19233970_1407007_2894_1.java : lines 19 to 19 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_21977649_21974806_3226_1.java : lines 28 to 28 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_28368275_4551263_275_0.java : lines 70 to 70 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_29030675_29030311_4317_0.java : lines 113 to 113 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_30738173_30737475_899_0.java : lines 10 to 10 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_34150316_27451058_1104_0.java : lines 5 to 5 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_3444682_3391794_1750_0.java : lines 107 to 107 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_34703506_34703489_1075_0.java : lines 18 to 18 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_36029144_12942133_2377_0.java : lines 16 to 16 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_36253021_36252941_1474_2.java : lines 4 to 9 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_37190381_37190240_4585_0.java : lines 32 to 32 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_40117210_40116072_387_0.java : lines 14 to 14 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_41283418_41278712_1546_0.java : lines 53 to 53 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_41429756_41429574_966_2.java : lines 4 to 4 ==> Potential violation of Law of Demeter (static property access) (Design)
# sample_pmd/lawofdemeter/Code_4144032_4137164_3029_2.java : lines 52 to 52 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_41726027_41725440_1670_0.java : lines 7 to 7 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_42325178_42325031_3218_5.java : lines 10 to 10 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_43066845_43066779_326_2.java : lines 12 to 12 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_46212898_21930969_3102_1.java : lines 18 to 18 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_47892669_47892433_540_0.java : lines 4 to 5 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_48144873_48144718_512_4.java : lines 30 to 31 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_50924880_50923725_188_0.java : lines 70 to 70 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_52884114_52881288_3261_0.java : lines 3 to 15 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_57006821_57005709_548_3.java : lines 4 to 4 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_57172714_57171656_601_2.java : lines 6 to 10 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_57634179_57491231_1747_2.java : lines 11 to 11 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_57742941_57742900_165_4.java : lines 5 to 5 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_60525856_60519252_1210_2.java : lines 12 to 12 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_61265614_26387003_942_0.java : lines 4 to 8 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_61630502_61596185_420_0.java : lines 15 to 15 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_63012816_62226765_732_0.java : lines 12 to 12 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/lawofdemeter/Code_63034407_63033622_1086_0.java : lines 16 to 16 ==> Potential violation of Law of Demeter (object not created locally) (Design)
# sample_pmd/lawofdemeter/Code_69017069_69016234_2456_2.java : lines 3 to 7 ==> Potential violation of Law of Demeter (method chain calls) (Design)
# sample_pmd/linguisticnaming/Code_34381670_34375795_514_1.java : lines 82 to 150 ==> Linguistics Antipattern - The method 'hasThreeInSix' indicates linguistically it returns a boolean, but it returns 'String' (Code Style)
# sample_pmd/literalsfirstincomparisons/Code_16377979_16377754_3343_0.java : lines 42 to 42 ==> Position literals first in String comparisons (Best Practices)
# sample_pmd/localhomenamingconvention/Code_7925661_7920981_3585_0.java : lines 1 to 3 ==> The Local Home interface of a Session EJB should be suffixed by LocalHome (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_10848530_10848335_878_4.java : lines 38 to 38 ==> Local variable 'format' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_14140205_14139759_3154_0.java : lines 5 to 5 ==> Local variable 'runtime' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_14703763_14675964_2427_5.java : lines 17 to 17 ==> Local variable 'code' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_1563588_1563570_2154_0.java : lines 3 to 3 ==> Local variable 'value' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_16210261_16209606_2176_0.java : lines 53 to 53 ==> Local variable 'inOrderY' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_16569924_16553157_4963_1.java : lines 14 to 14 ==> Local variable 'br' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_17059633_17059575_1175_3.java : lines 22 to 30 ==> Local variable 'result' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_17677738_17591368_3397_0.java : lines 25 to 25 ==> Local variable 'result' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_17833499_17832210_1050_0.java : lines 22 to 22 ==> Local variable 'androidHttpTransport' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_21025073_21024996_371_0.java : lines 16 to 16 ==> Local variable 'randomColor' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_218390_218384_313_4.java : lines 4 to 4 ==> Local variable 'obj' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_22186042_22185683_1926_2.java : lines 23 to 23 ==> Local variable 'stream' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_22213277_22120423_1950_1.java : lines 25 to 25 ==> Local variable 'ais' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_22540329_22540108_2398_2.java : lines 10 to 10 ==> Local variable 'greeting' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_23951795_23930630_1071_2.java : lines 17 to 17 ==> Local variable 'fis' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_24186440_24186246_1013_7.java : lines 46 to 46 ==> Local variable 'item' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_24522521_24522363_756_0.java : lines 4 to 13 ==> Local variable 't' could be declared final (Code Style)
# sample_pmd/localvariablecouldbefinal/Code_26707653_26707314_1895_7.java : lines 4 to 4 ==> Local variable 's1' could be declared final (Code Style)
# ...
# sample_pmd/systemprintln/Code_11580733_6892294_1773_0.java : lines 27 to 27 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_13312111_13311700_163_0.java : lines 6 to 6 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_13613848_13611292_2362_0.java : lines 4 to 4 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_14865264_14865124_919_0.java : lines 5 to 5 ==> System.out.print is used (Best Practices)
# sample_pmd/systemprintln/Code_15735148_15735079_299_0.java : lines 5 to 5 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_20514241_20514003_861_0.java : lines 7 to 7 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_20978326_20978138_92_1.java : lines 22 to 22 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_25590113_25590057_1698_0.java : lines 11 to 11 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_27031422_27031303_92_0.java : lines 3 to 3 ==> System.out.print is used (Best Practices)
# sample_pmd/systemprintln/Code_27661415_27661379_695_2.java : lines 3 to 3 ==> System.out.print is used (Best Practices)
# sample_pmd/systemprintln/Code_29415372_29414507_684_4.java : lines 7 to 7 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_31429572_31429136_3885_3.java : lines 45 to 45 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_35435781_35435577_259_5.java : lines 9 to 9 ==> System.out.print is used (Best Practices)
# sample_pmd/systemprintln/Code_36252804_36252761_1649_1.java : lines 9 to 9 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_36562509_36562184_2580_0.java : lines 45 to 45 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_38250424_38250274_4128_2.java : lines 142 to 142 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_41389123_35554796_922_1.java : lines 45 to 45 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_4215715_4215698_280_0.java : lines 4 to 4 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_50451385_50451063_489_0.java : lines 7 to 7 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_55671510_55671460_2769_0.java : lines 5 to 5 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_59925683_59925448_9_0.java : lines 6 to 6 ==> System.out.println is used (Best Practices)
# sample_pmd/systemprintln/Code_65966209_18280442_3130_0.java : lines 26 to 26 ==> System.out.print is used (Best Practices)
# sample_pmd/testclasswithouttestcases/Code_25465014_14082004_2395_1.java : lines 2 to 38 ==> This class name ends with Test but contains no test cases (Error Prone)
# sample_pmd/toofewbranchesforaswitchstatement/Code_7001298_7000736_998_1.java : lines 49 to 111 ==> A switch with less than three branches is inefficient, use a if statement instead. (Performance)
# sample_pmd/toomanystaticimports/Code_27475428_27281599_974_0.java : lines 1 to 259 ==> Too many static imports may lead to messy code (Code Style)
# sample_pmd/uncommentedemptyconstructor/Code_68704524_68703671_72_12.java : lines 14 to 15 ==> Document empty constructor (Documentation)
# sample_pmd/uncommentedemptymethodbody/Code_17010246_17010132_2038_0.java : lines 7 to 8 ==> Document empty method body (Documentation)
# sample_pmd/unconditionalifstatement/Code_51962206_51962084_480_4.java : lines 5 to 5 ==> Do not use if statements that are always true or always false (Error Prone)
# sample_pmd/unnecessarybooleanassertion/Code_7515938_2730365_283_3.java : lines 10 to 10 ==> assertTrue(true) or similar statements are unnecessary (Error Prone)
# sample_pmd/unnecessarycasechange/Code_48064157_48053127_402_0.java : lines 59 to 59 ==> Using equalsIgnoreCase() is cleaner than using toUpperCase/toLowerCase().equals(). (Error Prone)
# sample_pmd/unnecessarycast/Code_61458404_61457890_700_0.java : lines 12 to 12 ==> Avoid unnecessary casts (Code Style)
# sample_pmd/unnecessaryconversiontemporary/Code_30507860_30507052_1598_2.java : lines 28 to 28 ==> Avoid unnecessary temporaries when converting primitives to Strings (Error Prone)
# sample_pmd/unnecessaryfullyqualifiedname/Code_32098592_31997402_1650_1.java : lines 37 to 37 ==> Unnecessary use of fully qualified name 'javax.swing.GroupLayout' due to existing import 'javax.swing.*' (Code Style)
# sample_pmd/unnecessaryimport/Code_37035612_37035104_1688_2.java : lines 5 to 5 ==> Unused import 'java.util.Collections' (Code Style)
# sample_pmd/unnecessaryimport/Code_52721247_52721036_467_0.java : lines 1 to 1 ==> Unused import 'java.util.*' (Code Style)
# sample_pmd/unnecessarylocalbeforereturn/Code_32409438_32409324_1383_2.java : lines 18 to 18 ==> Consider simply returning the value vs storing it in local variable 'iob' (Code Style)
# sample_pmd/unnecessarymodifier/Code_41510810_41496526_1254_7.java : lines 21 to 21 ==> Unnecessary modifier 'final' on resource specification 'expensesReader': resource specifications are implicitly final (Code Style)
# sample_pmd/unnecessaryreturn/Code_61584552_61584508_300_4.java : lines 130 to 130 ==> Avoid unnecessary return statements (Code Style)
# sample_pmd/unsynchronizedstaticformatter/Code_4548586_4548252_3599_0.java : lines 26 to 26 ==> Static Formatter objects should be accessed in a synchronized manner (Multithreading)
# sample_pmd/unusedassignment/Code_25865974_25863782_1139_25.java : lines 8 to 8 ==> The initializer for variable 'returnValue' is never used (overwritten on line 12) (Best Practices)
# sample_pmd/unusedassignment/Code_28153592_25538905_47_0.java : lines 220 to 220 ==> The initializer for variable 'strMessageDesc' is never used (overwritten on line 225) (Best Practices)
# sample_pmd/unusedassignment/Code_28441470_28440540_3252_0.java : lines 6 to 6 ==> The initializer for variable 'numbers' is never used (overwritten on line 9) (Best Practices)
# sample_pmd/unusedformalparameter/Code_24689280_24689024_904_3.java : lines 6 to 6 ==> Avoid unused constructor parameters such as 'description'. (Best Practices)
# sample_pmd/unusedlocalvariable/Code_30805266_27021899_702_0.java : lines 147 to 147 ==> Avoid unused local variables such as 'sorted'. (Best Practices)
# sample_pmd/unusedlocalvariable/Code_46829305_46829211_584_1.java : lines 7 to 7 ==> Avoid unused local variables such as 'MMessage'. (Best Practices)
# sample_pmd/unusedlocalvariable/Code_58622747_58622280_1259_0.java : lines 3 to 3 ==> Avoid unused local variables such as 'is'. (Best Practices)
# sample_pmd/unusednullcheckinequals/Code_64316848_64316334_2568_3.java : lines 32 to 32 ==> Invoke equals() on the object you've already ensured is not null (Error Prone)
# sample_pmd/unusedprivatefield/Code_10148462_10147628_3229_0.java : lines 2 to 2 ==> Avoid unused private fields such as 'textField'. (Best Practices)
# sample_pmd/unusedprivatefield/Code_11995288_11991194_1722_2.java : lines 3 to 3 ==> Avoid unused private fields such as 'value'. (Best Practices)
# sample_pmd/unusedprivatefield/Code_26669851_26669333_659_2.java : lines 4 to 4 ==> Avoid unused private fields such as 'userId'. (Best Practices)
# sample_pmd/unusedprivatefield/Code_47743621_47742818_895_0.java : lines 2 to 2 ==> Avoid unused private fields such as 'emails'. (Best Practices)
# sample_pmd/unusedprivatefield/Code_55786106_31219169_157_0.java : lines 2 to 2 ==> Avoid unused private fields such as 'awtAppClassName'. (Best Practices)
# sample_pmd/unusedprivatemethod/Code_18914623_18914341_5366_4.java : lines 2 to 2 ==> Avoid unused private methods such as 'decodeColor(String)'. (Best Practices)
# sample_pmd/unusedprivatemethod/Code_42657033_42647990_4467_0.java : lines 2 to 2 ==> Avoid unused private methods such as 'removeTheDot(Number)'. (Best Practices)
# sample_pmd/unusedprivatemethod/Code_46602638_46602432_1210_0.java : lines 6 to 6 ==> Avoid unused private methods such as 'buttonPressed(int)'. (Best Practices)
# sample_pmd/usearraylistinsteadofvector/Code_15332777_15332733_3545_0.java : lines 7 to 7 ==> Use ArrayList instead of Vector (Performance)
# sample_pmd/usearraysaslist/Code_59013385_59012725_579_0.java : lines 21 to 21 ==> Use asList instead of tight loops (Performance)
# sample_pmd/usecollectionisempty/Code_49207452_49207357_1280_0.java : lines 37 to 37 ==> Substitute calls to size() == 0 (or size() != 0, size() > 0, size() < 1) with calls to isEmpty() (Best Practices)
# sample_pmd/usecorrectexceptionlogging/Code_41357831_41357396_545_0.java : lines 78 to 78 ==> Use the correct logging statement for logging exceptions (Error Prone)
# sample_pmd/usediamondoperator/Code_12321199_12321177_3187_0.java : lines 2 to 2 ==> Explicit type arguments can be replaced by Diamond Operator (Code Style)
# sample_pmd/usediamondoperator/Code_16398421_16398334_1443_1.java : lines 4 to 4 ==> Explicit type arguments can be replaced by Diamond Operator (Code Style)
# sample_pmd/usediamondoperator/Code_32970294_32969667_2246_7.java : lines 16 to 16 ==> Explicit type arguments can be replaced by Diamond Operator (Code Style)
# sample_pmd/usediamondoperator/Code_39394076_39387987_1692_0.java : lines 3 to 3 ==> Explicit type arguments can be replaced by Diamond Operator (Code Style)
# sample_pmd/useequalstocomparestrings/Code_39890726_10909251_318_0.java : lines 12 to 12 ==> Use equals() to compare strings instead of '==' or '!=' (Error Prone)
# sample_pmd/useindexofchar/Code_8518549_8518359_3266_0.java : lines 8 to 8 ==> String.indexOf(char) is faster than String.indexOf(String). (Performance)
# sample_pmd/useiostreamswithapachecommonsfileitem/Code_21764544_21643724_1507_0.java : lines 11 to 11 ==> Avoid memory intensive FileItem.get() or FileItem.getString() (Performance)
# sample_pmd/uselessoperationonimmutable/Code_9779502_9779407_2461_1.java : lines 9 to 9 ==> An operation on an Immutable object (String, BigDecimal or BigInteger) wont change the object itself (Error Prone)
# sample_pmd/uselessoverridingmethod/Code_36136849_36136436_4506_0.java : lines 8 to 11 ==> Overriding method merely calls super (Design)
# sample_pmd/uselessparentheses/Code_51638739_51638015_3305_2.java : lines 4 to 4 ==> Useless parentheses. (Code Style)
# sample_pmd/uselessparentheses/Code_66731315_66731263_1275_0.java : lines 38 to 38 ==> Useless parentheses. (Code Style)
# sample_pmd/uselessparentheses/Code_8585151_8572430_4134_1.java : lines 6 to 6 ==> Useless parentheses. (Code Style)
# sample_pmd/uselessstringvalueof/Code_13642244_13641678_317_0.java : lines 35 to 35 ==> No need to call String.valueOf to append to a string. (Performance)
# sample_pmd/uselocalewithcaseconversions/Code_12729335_11031244_90_0.java : lines 42 to 42 ==> When doing a String.toLowerCase()/toUpperCase() call, use a Locale (Error Prone)
# sample_pmd/usenotifyallinsteadofnotify/Code_42474915_42427491_323_10.java : lines 8 to 8 ==> Call Thread.notifyAll() rather than Thread.notify() (Multithreading)
# sample_pmd/useproperclassloader/Code_43648654_43609665_3933_0.java : lines 6 to 6 ==> In J2EE, getClassLoader() might not work as expected.  Use Thread.currentThread().getContextClassLoader() instead. (Error Prone)
# sample_pmd/usestandardcharsets/Code_52389163_29949303_3290_0.java : lines 7 to 7 ==> Please use StandardCharsets constants (Best Practices)
# sample_pmd/usestringbufferforstringappends/Code_25307705_25305933_1038_0.java : lines 26 to 26 ==> Prefer StringBuilder (non-synchronized) or StringBuffer (synchronized) over += for concatenating strings (Performance)
# sample_pmd/usestringbufferlength/Code_56460558_56460314_207_0.java : lines 51 to 51 ==> This is an inefficient use of StringBuffer.toString; call StringBuffer.length instead. (Performance)
# sample_pmd/usetrywithresources/Code_22880519_22879469_4290_1.java : lines 115 to 122 ==> Consider using a try-with-resources statement instead of explicitly closing the resource (Best Practices)
# sample_pmd/useutilityclass/Code_14488336_14488201_2074_0.java : lines 3 to 10 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_15861897_15861878_2836_0.java : lines 1 to 16 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_19535494_19535462_43_10.java : lines 1 to 28 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_20187927_20187326_306_0.java : lines 1 to 20 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_24378491_24378347_5192_0.java : lines 1 to 6 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_40269978_34355062_3501_0.java : lines 3 to 14 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_40492737_40491846_2605_0.java : lines 6 to 30 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_42394603_42394386_276_1.java : lines 2 to 52 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_53824439_10174898_1565_0.java : lines 1 to 31 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_55216194_55214924_3625_0.java : lines 1 to 44 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_62996116_62995897_688_13.java : lines 6 to 26 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_63957580_63957173_90_29.java : lines 1 to 13 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/useutilityclass/Code_68983417_68983063_1005_3.java : lines 1 to 20 ==> All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning. (Design)
# sample_pmd/usevarargs/Code_21441866_21441701_3848_0.java : lines 2 to 2 ==> Consider using varargs for methods or constructors which take an array the last parameter. (Best Practices)
# sample_pmd/usevarargs/Code_59754698_59754409_130_2.java : lines 2 to 2 ==> Consider using varargs for methods or constructors which take an array the last parameter. (Best Practices)
# sample_pmd/whileloopsmustusebraces/Code_58493191_58492922_844_0.java : lines 4 to 5 ==> Avoid using while statements without curly braces (Code Style)
# sample_pmd/whileloopwithliteralboolean/Code_63449225_63448699_597_2.java : lines 18 to 28 ==> The loop can be simplified. (Best Practices)
