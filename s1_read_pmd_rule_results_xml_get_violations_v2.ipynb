# %%
import time
from datetime import timedelta

import html
import re

import numpy as np
import pandas as pd
import xml.etree.ElementTree as et

import dask
import dask.dataframe as dd
import dask.bag as bd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# %%
##########################################################
#Step 1. Format 'pmd_rules_results.xml' from Linux terminal#
##########################################################
# -'pmd_rules_results.xml' is not properly formated
# -We used linux format command to format 'pmd_rules_results.xml' to save it in 'pmd_rules_results_fmt.xml'
# $  xmllint --format pmd_rules_results.xml > pmd_rules_results_fmt.xml
##############################################################################
#Step2. Remove some lines in 'test_flaws_rem_sm_tags_fmt' from Linux terminal#
##############################################################################
# remove lines 1 to 2 and the last line of the 'pmd_rules_results_fmt.xml'
# MacOS $  sed -i '' '1,2d;$d' pmd_rules_results_fmt.xml 
# Linux  $  sed -i '1,2d;$d' pmd_rules_results_fmt.xml 
# blocksize breaks it into partitions
#pmd_rules_result_bd = bd.read_text('pmd_rules_results_fmt.xml', blocksize='10MB')
pmd_rules_result_bd = bd.read_text('pmd_rules_results_fmt.xml', blocksize='10MB', linedelimiter='</violation>\n')
#pmd_rules_result_bd = bd.read_text('pmd_rules_results_fmt.xml', blocksize=1e8, linedelimiter='</violation>\n')
#pmd_rules_result_bd = bd.read_text('pmd_rules_results_fmt.xml', blocksize=None, linedelimiter='</violation>\n')
#pmd_rules_result_bd = bd.read_text('pmd_rules_results.xml', linedelimiter='</violation>\n')

# %%
# check to see number of partitions
# find the number of partitions
#pmd_rules_result_bg.npartitions # or
pmd_rules_result_bd
# Out:
# dask.bag<bag-from-delayed, npartitions=558>

# %%
# look at the first row
pmd_rules_result_bd.take(1)
# Out:
# ('  <file name="/scale_wlg_nobackup/filesets/nobackup/uoo03396/SfTI_project_nobackup/SfTI_Projects/StackOverflow_project/my_codesnippet_analysis/codesnippets_java/Code_10000096_9914015_1959_0.java">\n    <violation beginline="1" endline="11" begincolumn="43" endcolumn="1" rule="UseUtilityClass" ruleset="Design" class="Code_10000096_9914015_1959_0" externalInfoUrl="https://pmd.github.io/pmd-6.39.0/pmd_rules_java_design.html#useutilityclass" priority="3">\nAll methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning.\n</violation>\n',)

# %%
# look at the first 50 row
#pmd_rules_result_bd.take(50)

# %% [markdown]
# ### We are intrested in getting the 'violation'
# - so we can get rid of the files
# - then filter

# %%
# replace all the '<file>' with '</file>' so that we can access it using xml.etree.ElementTree
violations_rows_bd = pmd_rules_result_bd.map(lambda line: re.sub(r'\s*<\s*file.*>|.*/file>', '', line))

# %%
# look at the first row
violations_rows_bd.take(1)
# Out:
# ('\n    <violation beginline="1" endline="11" begincolumn="43" endcolumn="1" rule="UseUtilityClass" ruleset="Design" class="Code_10000096_9914015_1959_0" externalInfoUrl="https://pmd.github.io/pmd-6.39.0/pmd_rules_java_design.html#useutilityclass" priority="3">\nAll methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning.\n</violation>\n',)

# %%
# look at the first 50 row
#violations_rows_bd.take(50)

# %%
#filter only <violation ...
# Regex can also be applied here
#violations_rows_top_bd = violations_rows_bd.filter(lambda line: re.findall(r'\s*<violation', line))
violations_rows_bd = violations_rows_bd.filter(lambda line: line.find('<violation' or '< violation') >= 0)

# %%
# look at the first row
violations_rows_bd.take(1)
# Out:
# ('\n    <violation beginline="1" endline="11" begincolumn="43" endcolumn="1" rule="UseUtilityClass" ruleset="Design" class="Code_10000096_9914015_1959_0" externalInfoUrl="https://pmd.github.io/pmd-6.39.0/pmd_rules_java_design.html#useutilityclass" priority="3">\nAll methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning.\n</violation>\n',)

# %%
# look at the first 50 row
#violations_rows_bd.take(50)

# %% [markdown]
# ### Use ElementTree to get all the attrbutes and text in xmlor html tags

# %%
# This will give us just the attributes in the violation tag: <violation ...>
#violations_rows_bd = violations_rows_bd.map(lambda row: et.fromstring(row).attrib)

# %%
# This will give us just the text enclosed in the violation tag: <violation ...>
#violations_rows_bd = violations_rows_bd.map(lambda row: {'text':et.fromstring(row).text})

# %% [markdown]
# - To get both the the attrbutes and text in the violation tag
#     - We use add_text_to_dict_attrb() to achieve that

# %%
def add_text_to_dict_attrb(dictionary, txt):
    txt = txt.strip('\n')
    dictionary['text'] = txt
    return dictionary

# %% [raw]
# def add_text_to_dict_attrb(dictionary, txt):
#     #change some key names class to classname and method to classmethod
#     #dictionary['classname'] = dictionary.pop('class')
#     #dictionary['classmethod'] = dictionary.pop('method')
#     #remove the method since it is problematic
#     dictionary.pop('method', None)
#     dictionary.pop('externalInfoUrl', None)
#     # remove the \n in string
#     txt = txt.strip('\n')
#     #add 'text' as a key in the dict holding the actual text
#     dictionary['text'] = txt
#     return dictionary

# %%
# This will give us both the attributes in the violation tag and the text enclosed in the violation tag:
# <violation ...> ... </violation>
violations_rows_bd = violations_rows_bd.map(lambda row:  add_text_to_dict_attrb(et.fromstring(row).attrib, et.fromstring(row).text))

# %%
# look at the first row
violations_rows_bd.take(1)
# Out:
# ({'beginline': '1',
#   'endline': '11',
#   'begincolumn': '43',
#   'endcolumn': '1',
#   'rule': 'UseUtilityClass',
#   'ruleset': 'Design',
#   'class': 'Code_10000096_9914015_1959_0',
#   'externalInfoUrl': 'https://pmd.github.io/pmd-6.39.0/pmd_rules_java_design.html#useutilityclass',
#   'priority': '3',
#   'text': 'All methods are static.  Consider using a utility class instead. Alternatively, you could add a private constructor or make the class abstract to silence this warning.'},)

# %%
# look at the first 50 row
#violations_rows_bd.take(50)

# %%
# Convert Bags to Dataframes
df = violations_rows_bd.to_dataframe()

# %%
# View Stucture
df
# Out:
# Dask DataFrame Structure:
#                 beginline endline begincolumn endcolumn    rule ruleset   class externalInfoUrl priority    text
# npartitions=558
#                    object  object      object    object  object  object  object          object   object  object
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# ...                   ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
#                       ...     ...         ...       ...     ...     ...     ...             ...      ...     ...
# Dask Name: to_dataframe, 1674 tasks

# %%
df.partitions[1].compute()
# Out:
#       beginline endline begincolumn endcolumn                        rule  \
# 0            12      12          11        27   LocalVariableCouldBeFinal
# 1            17      17           5        22               SystemPrintln
# 2            11      37          43         1             UseUtilityClass
# 3            11      37           8         1      ClassNamingConventions
# 4            13      13          29        42  MethodArgumentCouldBeFinal
# ...         ...     ...         ...       ...                         ...
# 24052         3      10          42         1             UseUtilityClass
# 24053         3      10           8         1      ClassNamingConventions
# 24054         5       5          25        37  MethodArgumentCouldBeFinal
# 24055         1       4           8         1      ClassNamingConventions
# 24056         1      18          44         1             UseUtilityClass
#
#               ruleset                          class  \
# 0          Code Style  Code_10334164_10333780_1673_0
# 1      Best Practices  Code_10334164_10333780_1673_0
# 2              Design   Code_10334290_10333934_802_0
# 3          Code Style   Code_10334290_10333934_802_0
# 4          Code Style   Code_10334290_10333934_802_0
# ...               ...                            ...
# 24052          Design    Code_1066606_1066557_1858_2
# 24053      Code Style    Code_1066606_1066557_1858_2
# 24054      Code Style    Code_1066606_1066557_1858_2
# 24055      Code Style  Code_10666159_10666139_1999_0
# 24056          Design  Code_10666306_10666127_1643_0
#
#                                          externalInfoUrl priority  \
# 0      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 1      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        2
# 2      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 3      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# 4      https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# ...                                                  ...      ...
# 24052  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 24053  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# 24054  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
# 24055  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        1
# 24056  https://pmd.github.io/pmd-6.39.0/pmd_rules_jav...        3
#
#                                                     text
# 0             Local variable 't' could be declared final
# 1                             System.out.println is used
# 2      All methods are static.  Consider using a util...
# 3      The class name 'Code_10334290_10333934_802_0' ...
# 4      Parameter 'args' is not assigned and could be ...
# ...                                                  ...
# 24052  All methods are static.  Consider using a util...
# 24053  The class name 'Code_1066606_1066557_1858_2' d...
# 24054  Parameter 'args' is not assigned and could be ...
# 24055  The class name 'Code_10666159_10666139_1999_0'...
# 24056  All methods are static.  Consider using a util...
#
# [24057 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['beginline', 'endline', 'begincolumn', 'endcolumn', 'rule', 'ruleset',
#        'class', 'externalInfoUrl', 'priority', 'text'],
#       dtype='object')

# %%
#Index will not be particularly meaningful. Use reindex afterwards if necessary.
df.index
# Out:
# Dask Index Structure:
# npartitions=558
#     int64
#       ...
#     ...
#       ...
#       ...
# dtype: int64
# Dask Name: to_dataframe, 2232 tasks

# %%
df.npartitions
# Out:
# 558

# %%
int(df.npartitions/2)
# Out:
# 279

# %% [raw]
# len_dict = {}
# for i in range(0, int(df.npartitions)):
#     df1 = df.partitions[i].compute()
#     key = '{}'.format(i)
#     value = df1.shape[0]
#     len_dict[key]=value
#     df1.to_csv('pmdcodesnippetsviolations_csv/PMDJavaCodeSnippetsViolations{}.csv'.format(i), sep=',', index=False)
# Empty Task 269 completed!
# Empty Task 270 completed!
# Empty Task 271 completed!
# Empty Task 272 completed!
# Empty Task 273 completed!
# Empty Task 274 completed!
# Empty Task 275 completed!
# Empty Task 276 completed!
# Empty Task 277 completed!
# Empty Task 278 completed!
# Empty Task 279 completed!
# Empty Task 280 completed!
# Empty Task 281 completed!
# Empty Task 282 completed!
# Empty Task 283 completed!
# Empty Task 284 completed!
# Empty Task 285 completed!
# Empty Task 286 completed!
# Empty Task 287 completed!
# Empty Task 288 completed!
# Empty Task 289 completed!
# Empty Task 290 completed!
# Empty Task 291 completed!
# Empty Task 292 completed!
# Empty Task 293 completed!
# Empty Task 294 completed!
# Empty Task 295 completed!
# Empty Task 296 completed!
# Empty Task 297 completed!
# Empty Task 298 completed!
# Empty Task 299 completed!
# Empty Task 300 completed!
# Empty Task 301 completed!
# Empty Task 302 completed!
# Empty Task 303 completed!
# Empty Task 304 completed!
# Empty Task 305 completed!
# Empty Task 306 completed!
# Empty Task 307 completed!
# Empty Task 308 completed!
# Empty Task 309 completed!
# Empty Task 310 completed!
# Empty Task 311 completed!
# Empty Task 312 completed!
# Empty Task 313 completed!
# Empty Task 314 completed!
# Empty Task 315 completed!
# Empty Task 316 completed!
# Empty Task 317 completed!
# Empty Task 318 completed!
# Empty Task 319 completed!
# Empty Task 320 completed!
# Empty Task 321 completed!
# Empty Task 322 completed!
# Empty Task 323 completed!
# Empty Task 324 completed!
# Empty Task 325 completed!
# Empty Task 326 completed!
# Empty Task 327 completed!
# Empty Task 328 completed!
# Empty Task 329 completed!
# Empty Task 330 completed!
# Empty Task 331 completed!
# Empty Task 332 completed!
# Empty Task 333 completed!
# Empty Task 334 completed!
# Empty Task 335 completed!
# Empty Task 336 completed!
# Empty Task 337 completed!
# Empty Task 338 completed!
# Empty Task 339 completed!
# Empty Task 340 completed!
# Empty Task 341 completed!
# Empty Task 342 completed!
# Empty Task 343 completed!
# Empty Task 344 completed!
# Empty Task 345 completed!
# Empty Task 346 completed!
# Empty Task 347 completed!
# Empty Task 348 completed!
# Empty Task 349 completed!
# Empty Task 350 completed!
# Empty Task 351 completed!
# Empty Task 352 completed!
# Empty Task 353 completed!
# Empty Task 354 completed!
# Empty Task 355 completed!
# Empty Task 356 completed!
# Empty Task 357 completed!
# Empty Task 358 completed!
# Empty Task 359 completed!
# Empty Task 360 completed!
# Empty Task 361 completed!
# Empty Task 362 completed!
# Empty Task 363 completed!
# Empty Task 364 completed!
# Empty Task 365 completed!
# Empty Task 366 completed!
# Empty Task 367 completed!
# Empty Task 368 completed!
# Empty Task 369 completed!
# Empty Task 370 completed!
# Empty Task 371 completed!
# Empty Task 372 completed!
# Empty Task 373 completed!
# Empty Task 374 completed!
# Empty Task 375 completed!
# Empty Task 376 completed!
# Empty Task 377 completed!
# Empty Task 378 completed!
# Empty Task 379 completed!
# Empty Task 380 completed!
# Empty Task 381 completed!
# Empty Task 382 completed!
# Empty Task 383 completed!
# Empty Task 384 completed!
# Empty Task 385 completed!
# Empty Task 386 completed!
# Empty Task 387 completed!
# Empty Task 388 completed!
# Empty Task 389 completed!
# Empty Task 390 completed!
# Empty Task 391 completed!
# Empty Task 392 completed!
# Empty Task 393 completed!
# Empty Task 394 completed!
# Empty Task 395 completed!
# Empty Task 396 completed!
# Empty Task 397 completed!
# Empty Task 398 completed!
# Empty Task 399 completed!
# Empty Task 400 completed!
# Empty Task 401 completed!
# Empty Task 402 completed!
# Empty Task 403 completed!
# Empty Task 404 completed!
# Empty Task 405 completed!
# Empty Task 406 completed!
# Empty Task 407 completed!
# Empty Task 408 completed!
# Empty Task 409 completed!
# Empty Task 410 completed!
# Empty Task 411 completed!
# Empty Task 412 completed!
# Empty Task 413 completed!
# Empty Task 414 completed!
# Empty Task 415 completed!
# Empty Task 416 completed!
# Empty Task 417 completed!
# Empty Task 418 completed!
# Empty Task 419 completed!
# Empty Task 420 completed!
# Empty Task 421 completed!
# Empty Task 422 completed!
# Empty Task 423 completed!
# Empty Task 424 completed!
# Empty Task 425 completed!
# Empty Task 426 completed!
# Empty Task 427 completed!
# Empty Task 428 completed!
# Empty Task 429 completed!
# Empty Task 430 completed!
# Empty Task 431 completed!
# Empty Task 432 completed!
# Empty Task 433 completed!
# Empty Task 434 completed!
# Empty Task 435 completed!
# Empty Task 436 completed!
# Empty Task 437 completed!
# Empty Task 438 completed!
# Empty Task 439 completed!
# Empty Task 440 completed!
# Empty Task 441 completed!
# Empty Task 442 completed!
# Empty Task 443 completed!
# Empty Task 444 completed!
# Empty Task 445 completed!
# Empty Task 446 completed!
# Empty Task 447 completed!
# Empty Task 448 completed!
# Empty Task 449 completed!
# Empty Task 450 completed!
# Empty Task 451 completed!
# Empty Task 452 completed!
# Empty Task 453 completed!
# Empty Task 454 completed!
# Empty Task 455 completed!
# Empty Task 456 completed!
# Empty Task 457 completed!
# Empty Task 458 completed!
# Empty Task 459 completed!
# Empty Task 460 completed!
# Empty Task 461 completed!
# Empty Task 462 completed!
# Empty Task 463 completed!
# Empty Task 464 completed!
# Empty Task 465 completed!
# Empty Task 466 completed!
# Empty Task 467 completed!
# Empty Task 468 completed!
# Empty Task 469 completed!
# Empty Task 470 completed!
# Empty Task 471 completed!
# Empty Task 472 completed!
# Empty Task 473 completed!
# Empty Task 474 completed!
# Empty Task 475 completed!
# Empty Task 476 completed!
# Empty Task 477 completed!
# Empty Task 478 completed!
# Empty Task 479 completed!
# Empty Task 480 completed!
# Empty Task 481 completed!
# Empty Task 482 completed!
# Empty Task 483 completed!
# Empty Task 484 completed!
# Empty Task 485 completed!
# Empty Task 486 completed!
# Empty Task 487 completed!
# Empty Task 488 completed!
# Empty Task 489 completed!
# Empty Task 490 completed!
# Empty Task 491 completed!
# Empty Task 492 completed!
# Empty Task 493 completed!
# Empty Task 494 completed!
# Empty Task 495 completed!
# Empty Task 496 completed!
# Empty Task 497 completed!
# Empty Task 498 completed!
# Empty Task 499 completed!
# Empty Task 500 completed!
# Empty Task 501 completed!
# Empty Task 502 completed!
# Empty Task 503 completed!
# Empty Task 504 completed!
# Empty Task 505 completed!
# Empty Task 506 completed!
# Empty Task 507 completed!
# Empty Task 508 completed!
# Empty Task 509 completed!
# Empty Task 510 completed!
# Empty Task 511 completed!
# Empty Task 512 completed!
# Empty Task 513 completed!
# Empty Task 514 completed!
# Empty Task 515 completed!
# Empty Task 516 completed!
# Empty Task 517 completed!
# Empty Task 518 completed!
# Empty Task 519 completed!
# Empty Task 520 completed!
# Empty Task 521 completed!
# Empty Task 522 completed!
# Empty Task 523 completed!
# Empty Task 524 completed!
# Empty Task 525 completed!
# Empty Task 526 completed!
# Empty Task 527 completed!
# Empty Task 528 completed!
# Empty Task 529 completed!
# Empty Task 530 completed!
# Empty Task 531 completed!
# Empty Task 532 completed!
# Empty Task 533 completed!
# Empty Task 534 completed!
# Empty Task 535 completed!
# Empty Task 536 completed!
# Empty Task 537 completed!
# Empty Task 538 completed!
# Empty Task 539 completed!
# Empty Task 540 completed!
# Empty Task 541 completed!
# Empty Task 542 completed!
# Empty Task 543 completed!
# Empty Task 544 completed!
# Empty Task 545 completed!
# Empty Task 546 completed!
# Empty Task 547 completed!
# Empty Task 548 completed!
# Empty Task 549 completed!
# Empty Task 550 completed!
# Empty Task 551 completed!
# Empty Task 552 completed!
# Empty Task 553 completed!
# Empty Task 554 completed!
# Empty Task 555 completed!
# Empty Task 556 completed!
# Empty Task 557 completed!

# %%
values = len_dict.values()

# %%
values
# Out:
# dict_values([24105, 24057, 23964, 24134, 24016, 24099, 24072, 24160, 24104, 24071, 24107, 23910, 24071, 23877, 24064, 24286, 24207, 24139, 24038, 24060, 23969, 24087, 23942, 23864, 23966, 24035, 23933, 23991, 24030, 23979, 23991, 24074, 24016, 23921, 24075, 24059, 24118, 24143, 23991, 24038, 24057, 24010, 24228, 24171, 24013, 24036, 24012, 24244, 24096, 24078, 24024, 24048, 24060, 24043, 24059, 24109, 24179, 24092, 24188, 24109, 24074, 23948, 23926, 24087, 24113, 24103, 24109, 24076, 24183, 24080, 24019, 24063, 24146, 24145, 24158, 24093, 24216, 24064, 24064, 24204, 24127, 24154, 24072, 24143, 24136, 24137, 24136, 24155, 24120, 24117, 24111, 24130, 24192, 24063, 24124, 24143, 24211, 24054, 24041, 24094, 24043, 24003, 24097, 24185, 24055, 24014, 24139, 24240, 24156, 24143, 24159, 24163, 24225, 24166, 24148, 24114, 24207, 24102, 24130, 24071, 24156, 24076, 24078, 24084, 24069, 24122, 23979, 24079, 24212, 24117, 24185, 24111, 24213, 23987, 24050, 23972, 24060, 24129, 24208, 24083, 24031, 24061, 24092, 24170, 24088, 24108, 24050, 24217, 24169, 24151, 24003, 24055, 24081, 24225, 24215, 24200, 24245, 24105, 24080, 24037, 24046, 24047, 24218, 24145, 24162, 17310, 24214, 24053, 24099, 24213, 24261, 24106, 24276, 24296, 24187, 24213, 24187, 24177, 24183, 24376, 24414, 24256, 24236, 24273, 24246, 24235, 24227, 24154, 24233, 24125, 24307, 24308, 24217, 24208, 24153, 24110, 24180, 24086, 24105, 24095, 24232, 24082, 24266, 8157])

# %%
total_len = sum(map(int, values))

# %%
print(total_len)
# Out:
# 4896537

# %%
counter = 0
for key, value in len_dict.items():
    if value <= 0:
        counter+=1
        #print (key)
    
print(counter)
# Out:
# 0
